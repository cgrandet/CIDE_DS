# %% [markdown]
# # Procesamiento del Lenguaje Natural, con Python
#
#
# # Índice
#
# #### Tema 1: Introducción
#
#
# * ¿Qué es un Lenguaje?
#
#
# * ¿Qué es el Procesamiento del Lenguaje Natural?
#
#
# * Herramientas en Python para NLP:
#     - NLTK
#     - SpaCy
#     - Gensim
#     - Scikit
#     - TensorFlow-Keras
#
#
# #### Tema 2: NLP - Conceptos y Preprocesamiento de texto
#
#
# * Conceptos:
#
#     - Corpus
#     - Bag of Words (BoW)
#     - Tokenización
#     - N-Grammas
#     - Stemming
#     - Lematización
#     - Stop-Words
#     - Parts of Speech (PoS)
#     - Named Entity Recognition (NER)
#
#
# * Normalización de textos: Preprocesamiento
#
#
# #### Tema 3: Analisis Automático de texto subjetivo (Clasificación de textos)
#
#
# * Introducción: Clasificación de textos con Naive Bayes
#
#
# * Clasificación de textos: Algoritmos de aprendizaje para la clasificación
#
#
# * Clasificación de textos: Redes Neuronales
#
#
# #### Tema 4: Topic Modeling (Clustering)
#
#
# * LSI: Latent Semantic Index
#
#
# * LDA: Latent Dirichlet Allocation
#
#
# * Visialización: pyLDAvis
#
#
# #### Tema 5: Uso de modelos pre-entrenado en "Hugging Face" (Transformers)
#
#
# * Clasificación
#
#
# * Traducción
#
#
# * Resumenes de textos
#
#
# #### Tema 6: Introducción a GPT3
#
#
# <hr>
#
#
# # Tema 1: Introducción
#
#
# ## ¿Qué es un Lenguaje?
#
#
# * Un Lenguajes es un conjunto potencialmente infinito de oraciones y sentencias de palabras construidas mediante reglas gramaticales, foneticas y de significación que rigen el propio lenguaje.
#
#
# * Nos encontramos con 3 tipos de lenguajes:
# <span></span><br><br>
#     - ***Lenguaje Natural***: Lengua o idioma que nace espontáneamente de un grupo de hablantes por la necesidad de establecer comunicación verbal. Ejm: Ingles, Castellano, Frances, Italiano, etc.
# <span></span><br><br>
#     - ***Lenguaje Formal***: Lenguajes diseñados para un ámbito de aplicación concreto, que se definen de manera precisa y libre de ambigüedad. Ejm: Matemático, Lógico, Musical, Programación (C, Java, Python, R, Scala, etc.)
# <span></span><br><br>
#     - ***Lenguaje Artificial***: Lenguajes diseñados antes de ser usados por sus parlantes. Es una mezcla entre los lenguajes naturales y formales. Ejm: Klingon.
#
#
#
# ## ¿Qué es el Procesamiento del Lenjuaje Natural?
#
#
# * El ***Procesamiento del Lenguaje Natural*** (NLP) es un campo que combina la ***Informática***, la ***Inteligencia Artificial*** y la ***Lingüística***; que tiene como objetivo, tratar la interacción entre los lenguajes humanos (lenguajes naturales) y los dispositivos informáticos.
#
#
# * El NLP abarca los siguientes campos:
#     - Recuperación de información
#     - Extracción y categorización de información
#     - Análisis automático de texto subjetivo (Análisis de sentimientos)
#     - Traducción automática
#     - Generación del lenguaje
#     - Questions & Answering (Chatbots)
#
#
# <img src="./imgs/000_nlp.png" style="width: 700px;"/>
#
#
#
# ## De la *Lingüística* al *Procesamiento del Lenguaje Natural*
#
# ### - Lingüística
#
#
# * La ***lingüística*** es el estudio científico del lenguaje, incluyendo su gramática, semántica y fonética.
#
#
# * En términos generales, un ***lingüista*** es cualquier persona que estudia un idioma.
#
#
# ### - Lingüística computacional
#
#
# * La lingüística computacional es el estudio de la lingüística utilizando las herramientas de la informática.
#
#
# ### - Procesamiento estadístico del lenguaje natural
#
#
# * La lingüística computacional también se conoce con el nombre de Procesamiento del Lenguaje Natural, para reflejar el enfoque más ingenieril o empírico de los métodos estadísticos aplicados a la Lingüistica.
#
#
# * El dominio estadístico del campo, lleva a menudo a que el ***NLP*** sea descrito como ***Procesamiento Estadístico del Lenguaje Natural***, para distanciarse (en la definición) de los métodos clásicos de la lingüística computacional.
#
#
# ### - Procesamiento del Lenguaje natural
#
#
# * Campo que combina la ***Informática***, la ***Inteligencia Artificial*** y la ***Lingüística***; que tiene como objetivo, tratar la interacción entre los lenguajes humanos (lenguajes naturales) y los dispositivos informáticos.
#
#
# ## Herramientas en Python para el NLP
#
#
# * Aunque existen bastante librería en Python destinadas al Procesamiento del Lenguaje Natural o a resolver determinadas partes del NLP, mostramos a continuación una serie de librería que vamos a utilizar en este curso:
# <span></span><br><br>
#     - ***NLTK*** (https://www.nltk.org/): Es una librería desarrollada por Steven Bird y Edward Loper para el NLP (principalmente en Inglés) que incorpora muchas funcionalidades como, corpus, recursos léxicos, algoritmos de aprendizaje para el NLP, etc.
# <span></span><br><br>
#     - ***SpaCy*** (https://spacy.io/): Es una librería para el NLP incorpora funcionalidades como Tokenización, Lematización, PoS, NER, etc. en varios idiomas. A diferencia de NLTK que tienen fines de caracter didáctico, SpaCy esta pensado para explotarlo en entornos productivos.
# <span></span><br><br>
#     - ***Gensim*** (https://radimrehurek.com/gensim): Es una librería desarrollada por el Checo Radim Řehůřek, Ph.D, que tiene implementadas; entre otras cosas, algoritmos como el LSI y el LDA para la detección de tópicos (Topic Modeling)
# <span></span><br><br>
#     - ***Scikit*** (https://scikit-learn.org/): Es una librería que tiene implementada multitud de algoritmos de aprendizaje (regresión, clasificación, cluterización, reducción de la dimensionalidad) y funcionalidades para trabajar con estos algoritmos.
# <span></span><br><br>
#     - ***TensorFlow-Keras*** (https://www.tensorflow.org/): Es una librería desarrollada por Google para trabajar con Redes Neuronales (MLP, CNN, RNN). La versión 2 de TensorFlow hace uso del API de Keras para un desarrollo más sencillo.
#
#
# ## Bibliografía recomendada para NLP (en Inglés)
#
#
# 1. **Natural Language Processing with Python** de Steven Bird, Ewan Klein y Edward Loper. O'Reilly Media. Julio 2009.
#
# 2. **Applied Text Analysis with Python**, de Benjamin Bengfort, Rebecca Bilbro y Tony Ojeda. O'Reilly Media. Junio 2018.
#
# 3. **Natural Language Processing Crash Course for Beginners**, de AI Publishing. Agosto 2020.
#
# 4. **Transformers for Natural Language Processing**,  de Denis Rothman. Packt Publishing. Enero 2021.

# %% [markdown]
# # 02 - Clasificación de textos con Naive Bayes: Introducción
#
# * Uno de los temas interesantes del ***Procesamiento del Lenguaje Natural*** es el de la clasificación de textos.
#
#
# * Los problemas de clasificación se encuentran dentro del ***aprendizaje supervisado***, lo que significa que para la clasificación de texto previamente se tiene que disponer de una serie de texto etiquetados (o clasificados).
#
#
# * Por tanto para la clasificación de textos se necesita un ***array de características del texto*** (Bolsa de Palabras) y una ***etiqueta asociada*** a ese texto.
#
#
# * Uno de los clasificadores más sencillos de entender es el clasificador ***Naive Bayes***, que es un clasificador probabilístico que se basa en el ***teorema de Bayes***
#
# <hr>
#
# * Veamos a continuación como clasificar textos utilizando un clasificador ***Naive Bayes***:
#
# ### 1.- Probabilidad de que una palabra pertenezca a una etiqueta:
#
# * Definimos la probabilidad de que una **palabra** pertenezca a una **etiqueta** de la siguiente manera:
#
#
# $$P(etiqueta|palabra) = \frac{P(etiqueta) \cdot P(palabra|etiqueta)}{P(palabra)}$$
#
# * Veamos paso por paso como calcular la probabilidad que dada una palabra, esta pertenezca a una etiqueta:
#
#     1. **Probabilidad de la Palabra** - *P(palabra)*:
# <br>
#        $$P(palabra) = \frac{Nº \: apariciones \: palabra}{Nº \: palabras \: totales \: corpus}$$
# <br>
#     2. **Probabilidad de la Etiqueta** - *P(etiqueta)*:
# <br>
#        $$P(etiqueta) = \frac{Nº \: apariciones \: de \: palabras \: con \: esa \: etiqueta}{Nº \: palabras \: totales \: corpus}$$
# <br>
#     3. **Probabilidad de que una etiqueta pertenezca a una palabra** - *P(palabra|etiqueta)*:
# <br>
#        $$P(palabra|etiqueta) = \frac{Nº \: veces \: que \: aparece \: la \: palabra \: con \: esa \: etiqueta}{Nº \: apariciones \: de \: palabras \: con \: esa \: etiqueta}$$
# <br>
#
# ### 2.- Probabilidad de que un texto pertenezca a una etiqueta:
#
# * El clasificador ***Naive Bayes*** elige en primer lugar la ***etiqueta más probable*** para un texto, asumiendo que los textos los clasificamos "de primeras" sin tener información sobre el contenido del texto.
#
#
# * En segundo lugar mira las características individuales del texto (las palabras) asumiendo que todas las características son independientes entre sí. Esta suposición es la que hace "ingenuo" (Naive en ingles) al clasificador de Bayes ya que las características (las palabras) no son independientes entre sí.
#
#
# * Por tanto se define la probabilidad de que un documento pertenezca a una etiqueta como el producto de la probabilidad de la etiqueta junto al productos de las probabilidades particulares de cada palabra:
#
#
# $$P(etiqueta_j|documento) = P(etiqueta_j)  \cdot \prod_{etiqueta_j\in Etiquetas} P(palabra_i | etiqueta_j)$$
#
# <hr>
#
# ## Ejemplo:
#
# * Veamos a continuación como clasificar textos utilizando un clasificador ***Naive Bayes***, suponiendo que tenemos 5 textos clasificados cada unos de ellos por la temática "Real Madrid" o "Barça". Los textos serian los siguientes:
#
#     - **T1 (Real Madrid)**: Ronaldo Ronaldo Ronaldo Ronaldo Futbol
#     - **T2 (Real Madrid)**: Ronaldo Ramos Ramos Messi
#     - **T3 (Real Madrid)**: Ramos Ramos Ramos Ronaldo Messi Iniesta Futbol
#     - **T4 (Barça)**: Messi Messi Messi Iniesta Futbol Ronaldo
#     - **T5 (Barça)**: Messi Messi Iniesta Iniesta Iniesta Ramos Futbol
#
#
# #### Datos:
#
# * ***Documentos***:
#     - Número total de documentos = 5
#     - Número de documentos etiquetados como "Real Madrid" = 3
#     - Número de documentos etiquetados como "Barça" = 2
#     - P(Real Madrid) = 3/5
#     - P(Barça) = 2/5
#
#
# * ***Palabras***:
#     - Número total de palabras = 29
#     - Número total de palabras etiquetadas como Real Madrid = 16
#     - Número total de palabras etiquetadas como Barça = 13
#
# |Palabra|Apariciones|Apariciones(Real Madrid)|Apariciones(Barça)|P(palabra)|P(palabra/Real Madrid)|P(palabra/Barça)|
# |---|---|---|---|---|---|---|
# |Ronaldo|7|6|1|7/29|6/16|1/13|
# |Ramos|6|5|1|6/29|5/16|1/13|
# |Messi|7|2|5|7/29|2/16|5/13|
# |Iniesta|5|1|4|5/29|1/16|4/13|
# |Futbol|4|2|2|4/29|2/16|2/13|
#
# #### Clasificación:
# * Supongamos que tenemos el siguiente texto a clasificar:
#     - **$Doc_{new}$**: Ronaldo Ronaldo Messi Futbol
#
#
# * ***Clasificación del texto Tt1***:
#
# $$P(Real Madrid|Doc_{new}) = P(Real Madrid) \cdot P(Ronaldo|Real Madrid) \cdot P(Ronaldo|Real Madrid) \cdot P(Messi|Real Madrid) \cdot P(Futbol|Real Madrid)$$ $$ = 3/5 \cdot 6/16 \cdot 6/16 \cdot 2/16 \cdot 2/16 = 1.32\cdot10^{-3}$$
#
# <br>
#
# $$P(Barça|Doc_{new}) = P(Barça) \cdot P(Ronaldo|Barça) \cdot P(Ronaldo|Barça) \cdot P(Messi|Barça) \cdot P(Fútbol|Barça)$$ $$= 2/5 \cdot 1/13 \cdot 1/13 \cdot 5/13 \cdot 2/13 = 1.4\cdot10^{-4}$$
#
# * ***Resultado***: P(Real Madrid|$Doc_{new}$) = 1.32·10<sup>-3</sup> > P(Barça|$Doc_{new}$) = 1.4·10<sup>-4</sup> -> ***Clasificado como "Real Madrid"***

# %%
textos = [('Ronaldo Ronaldo Ronaldo Ronaldo Futbol', 'Real Madrid'),
          ('Ronaldo Ramos Ramos Messi', 'Real Madrid'),
          ('Ramos Ramos Ramos Ronaldo Messi Iniesta Futbol', 'Real Madrid'),
          ('Messi Messi Messi Iniesta Futbol Ronaldo', 'Barça'),
          ('Messi Messi Iniesta Iniesta Iniesta Ramos Futbol', 'Barça')]


def to_bow(textos, label='all'):
    """Función que dada una lista de textos etiquetados, devuelve una bolsa de palabras por frecuencia"""
    bow = dict()
    for text in textos:
        if text[1] == label or label == 'all':
            for word in text[0].split(' '):
                if word in bow:
                    bow[word] += 1
                else:
                    bow[word] = 1
    return bow

bow = to_bow(textos)
bow_madrid = to_bow(textos, 'Real Madrid')
bow_barsa = to_bow(textos, 'Barça')

# %%
print(bow)
print(bow_madrid)
print(bow_barsa)
# Out:
# {'Ronaldo': 7, 'Futbol': 4, 'Ramos': 6, 'Messi': 7, 'Iniesta': 5}
# {'Ronaldo': 6, 'Futbol': 2, 'Ramos': 5, 'Messi': 2, 'Iniesta': 1}
# {'Messi': 5, 'Iniesta': 4, 'Futbol': 2, 'Ronaldo': 1, 'Ramos': 1}

# %% [markdown]
# <hr>
#
#
# # Definición - Teorema de Bayes (Naive Bayes)
#
#
# ## - Teorema de Bayes
#
# * Uno de los clasificadores más sencillos de entender es el clasificador ***Naive Bayes***, que es un clasificador probabilístico que se basa en el ***Teorema de Bayes***.
#
#
# * El ***Teorema de Bayes*** define lo siguiente:
#
#
# <span style="font-size:20px">$$P(y|x) = \frac{P(x|y) \cdot P(y)}{P(x)}$$</span>
#
#
# * Con el ***Teorema de bayes podemos calcular la probabilidad $P(y|x)$***, que es la probabilidad de que un elemento 'x' pertenezca a una clase 'y', ***teniendo unicamente como datos***:
# <span></span><br><br>
#     + ***$P(x)$ - Probabilidad Marginal***: Probabilidad de los elementos 'x'.
# <span></span><br><br>
#     + ***$P(y)$ - Probabilidad a priori***: Probabilidad de las clases 'y'.
# <span></span><br><br>
#     + ***$P(x|y)$ - Probabilidad condicionada***: Probabilidad de los casos de cada clase.
#
#
# * Resumiendo, tenemos lo siguiente:
#
#
# <img src="./imgs/020_bayes.png" style="width: 400px;"/>
#
#
# ## - Naive Bayes
#
#
# * Una simplificación del Teorema de Bayes es ***asumir que las variables mediante las que se describen nuestros elementos son independientes***.
#
#
# * Si añadimos esta suposición a nuestro clasificador tenemos lo que se conoce como ***Naive Bayes*** (el Bayes Ingenuo), por lo que ***podemos calcular la probabilidad a posteriori*** (o la probabilidad de que un elemento pertenezca a una clase) como:
#
#
# <span style="font-size:20px">$$P(y=y_j|x) = P(x|y=y_j) \cdot P(y_j)$$</span>
#
#
# * Aunque en el ejemplo anterior nuestro conjunto de datos solo tenia una variable, cada elemento de nuestro Dataset podrá tener 'n' variables, las cuales asumimos que son independientes; por tanto, calculamos la ***probabilidad condicionada*** como:
#
#
# $$P(x|y=y_j) = P(x_1|y=y_j) \: \times \: ... \: \times \: P(x_n|y=y_j) = \prod_{i=1}^{n} P(x_i|y=y_j)$$
#
#
# * Por tanto ***calculamos la probabilidad a posteriori*** definida por el clasificador ***Naive Bayes*** como:
#
# <span style="font-size:20px">$$P(y=y_j|x) = P(y=y_j) \cdot \prod_{i=1}^{n} P(x_i|y=y_j)$$</span>

# %% [markdown]
# # 03 - NLTK: Clasificación de textos con Naive Bayes
#
# * En este notebook vamos a ver como crear un modelo que clasifique las frases según su polaridad (Positiva o Negativa).
#
#
# * Para ello tenemos 3 conjuntos de frases que son:
#     1. **Positivas**: Conjunto de frases clasificadas con polaridad positiva
#     2. **Negativas**: Conjunto de frases clasificadas con polaridad negativa
#     3. **Test**: Conjunto de frases de test a predecir.
#
#
# * El framework para la clasificación de texto (y para la clasificación en general) es el siguiente:
#
#     - ***Entrenamiento***:
#
#         1. Limpieza y ***normalización*** del texto
#         2. ***Extracción de características***: esto consiste en crear la estructura de datos necesaria para que la utilice el algoritmo de aprendizaje a usar
#         3. ***Algoritmo de Aprendizaje***: Dado el conjunto de características de los texto y la etiqueta (label) de los textos, el algoritmo de aprendizaje dará como resultado un **modelo**.
# <br><br>
#     - ***Predicción***:
#
#         1. Limpieza y ***normalización*** del texto a clasificar.
#         2. ***Extracción de características*** del texto a clasificar. Tanto este punto 2 como el anterior (1) deben de realizarse de la misma manera que en la fase de entrenamiento.
#         3. ***Predicción***: Dado el conjunto de características de los ***texto a predecir*** y el **modelo**, este devolverá la ***clasificación*** (o predicción) del texto.
#
#
# * Este framework lo podemos ver en la siguiente imagen:
#
# <img src="./imgs/009_Clasificacion_framework.png" style="width: 500px;"/>
#
#
# <hr>
#
#
# ## Ejemplo con NLTK:

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/carlosograndetcaballero/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import re
import nltk
import nltk.classify
from nltk.corpus import stopwords

positive = [('I love this car', 'positive'),
            ('This view is amazing', 'positive'),
            ('I feel great this morning', 'positive'),
            ('I am so excited about the concert', 'positive'),
            ('He is my best friend', 'positive'),
            ('Going well', 'positive'),
            ('Thank you', 'positive'),
            ('Hope you are doing well', 'positive'),
            ('I am very happy', 'positive'),
            ('Good for you', 'positive'),
            ('It is all good. I know about it and I accept it.', 'positive'),
            ('This is really good!', 'positive'),
            ('Tomorrow is going to be fun.', 'positive'),
            ('These are great apples today.', 'positive'),
            ('How about them apples? Thomas is a happy boy.', 'positive'),
            ('I love this sandwich.', 'positive'),
            ('This is an amazing place!', 'positive'),
            ('I feel very good about these beers.', 'positive'),
            ('This is my best work.', 'positive'),
            ('What an awesome view', 'positive')]

negative = [('I do not like this car', 'negative'),
            ('This view is horrible', 'negative'),
            ('I feel tired this morning', 'negative'),
            ('I am not looking forward to the concert', 'negative'),
            ('He is my enemy', 'negative'),
            ('I am a bad boy', 'negative'),
            ('This is not good', 'negative'),
            ('I am bothered by this', 'negative'),
            ('I am not connected with this', 'negative'),
            ('Sadistic creep you ass. Die.', 'negative'),
            ('All sorts of crazy and scary as hell.', 'negative'),
            ('Not his emails, no.', 'negative'),
            ('His father is dead. Returned obviously.', 'negative'),
            ('He has a bomb.', 'negative'),
            ('Too fast to be on foot. We cannot catch them.', 'negative'),
            ('I do not like this restaurant', 'negative'),
            ('I am tired of this stuff.', 'negative'),
            ("I can't deal with this", 'negative'),
            ('He is my sworn enemy!', 'negative'),
            ('My boss is horrible.', 'negative')]

test = [('I feel happy this morning', 'positive'),
        ('Larry is my friend', 'positive'),
        ('I do not like that man', 'negative'),
        ('My house is not great', 'negative'),
        ('Your song is annoying', 'negative'),
        ('The beer was good.', 'positive'),
        ('I do not enjoy my job', 'negative'),
        ("I feel amazing!", 'positive'),
        ('Gary is a friend of mine.', 'positive'),
        ("I can't believe I'm doing this.", 'negative')]

# %% [markdown]
# <hr>
#
#
# ## Normalización
#
# * En primer lugar vamos a pasar a normalizar las frases. Para ello realizaremos lo siguiente:
#
#     - Eliminamos los signos de puntuación
#     - Eliminamos las Stop-Words
#     - Pasamos el texto a minúsculas
#
# * Nos creamos una función que realice este procesamiento para las frases dadas.
#
#
# ***NOTA***: *Para este ejemplo en particular se hace una normalización muy básica pero suficiente para realizar este ejemplo con caracter didáctico*.

# %%
def normalize(sentenses):
    """normalizamos la lista de frases"""
    sen = []
    for (words, sentiment) in sentenses:
        words_filtered = []
        for word in words.split():
            word = re.sub(r'[^\w\s]', '', word).lower() # Eliminamos signos de puntuación y lo pasamos a minúsculas
            if len(word) > 2 and word not in stopwords.words(): # Filtramos stop words y las palabras con menos de 3 caracteres
                words_filtered.append(word)
        sen.append((words_filtered, sentiment))
    return sen

# %% [markdown]
# <hr>
#
#
# ## Extracción de características
#
# * El algoritmo de aprendizaje (Naive Bayes) necesita una determina estructura de datos de entrada para generar el modelo. Para ello necesitamos crear:
#
#     - Un Diccionario (CUIDADO no es un diccionario python) con todas las palabras del corpus.
#
#     - Una tupla que contenga en la primera posición un Booleano si por cada palabra del diccionario aparece o no la palabra de la frase. El segundo elemento de la tupla es la etiqueta de la frase.
#
#
# * Para ello creamos las siguientes 2 funciones:

# %%
def get_unique_words(sentenses):
    """Función que devuelve una lista con todas las palabras únicas que aparecen en las frases"""
    all_words = []
    for (words, sentiment) in sentenses:
        all_words.extend(words)
    return list(set(all_words))

def extract_features(document):
    """Función que crea el conjunto de entrenamiento del clasificador
       1: Toma todos los documentos del corpus
       2: Toma todas las palabras del corpus
       3: Escribre (True|False) si aparece cada palabra del corpus en la frase
    """
    document_words = set(document)
    features = {}
    for word in unique_words:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %% [markdown]
# * A continuación pasamos a crear el conjunto de entrenamiento:

# %%
# Normalizamos las frases
sentenses = normalize(positive+negative)

# Obtenemos las palabras del corpus (diccionario del corpus)
unique_words = get_unique_words(sentenses)

# Construimos el conjunto de entrenamiento
training_set = nltk.classify.apply_features(extract_features, sentenses)

print(training_set[0])
sentenses[0]
# Out:
# ({'contains(car)': True, 'contains(know)': False, 'contains(sandwich)': False, 'contains(bothered)': False, 'contains(scary)': False, 'contains(great)': False, 'contains(best)': False, 'contains(good)': False, 'contains(work)': False, 'contains(place)': False, 'contains(cant)': False, 'contains(horrible)': False, 'contains(catch)': False, 'contains(view)': False, 'contains(excited)': False, 'contains(like)': False, 'contains(crazy)': False, 'contains(really)': False, 'contains(accept)': False, 'contains(today)': False, 'contains(forward)': False, 'contains(fun)': False, 'contains(sadistic)': False, 'contains(ass)': False, 'contains(feel)': False, 'contains(well)': False, 'contains(sworn)': False, 'contains(apples)': False, 'contains(tired)': False, 'contains(boss)': False, 'contains(morning)': False, 'contains(thank)': False, 'contains(boy)': False, 'contains(sorts)': False, 'contains(going)': False, 'contains(emails)': False, 'contains(looking)': False, 'contains(fast)': False, 'contains(returned)': False, 'contains(obviously)': False, 'contains(deal)': False, 'contains(amazing)': False, 'contains(dead)': False, 'contains(tomorrow)': False, 'contains(restaurant)': False, 'contains(thomas)': False, 'contains(beers)': False, 'contains(connected)': False, 'contains(friend)': False, 'contains(stuff)': False, 'contains(foot)': False, 'contains(cannot)': False, 'contains(enemy)': False, 'contains(love)': True, 'contains(hope)': False, 'contains(bad)': False, 'contains(concert)': False, 'contains(happy)': False, 'contains(awesome)': False, 'contains(hell)': False, 'contains(father)': False, 'contains(bomb)': False, 'contains(creep)': False}, 'positive')
# (['love', 'car'], 'positive')

# %% [markdown]
# <hr>
#
#
# ## Algoritmo de Aprendizaje
#
# * Creamos un objeto de la clase NaiveBayesClassifier y llamamos al método train pasándole los datos de entrenamiento.
#
#
# * De esta manera ya tenemos el modelo creado para su uso asi como información relativa al modelo.

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# <hr>
#
#
# ## Predicción
#
# * Para la predicción vamos a utilizar el modelo creado para ello vamos a:
#     1. Normalizar las frases
#     2. Extracción de características de la frase
#     3. Predicción
#
# * Veamos a continuación como hacerlo y como clasificamos:

# %%
test = normalize(test)   # Normalizamos
for sen in test:
    sentense_features = extract_features(sen[0])   # Extracción de características
    polarity = classifier.classify(sentense_features)   # Clasificación
    print('Frase: ' + str(sen[0]))
    print('\tPolaridad: ' + sen[1] + ' - Predicción: ' + polarity + ' -> ' + ('BIEN' if polarity==sen[1] else 'MAL'))
# Out:
# Frase: ['feel', 'happy', 'morning']
# 	Polaridad: positive - Predicción: positive -> BIEN
# Frase: ['larry', 'friend']
# 	Polaridad: positive - Predicción: positive -> BIEN
# Frase: ['like']
# 	Polaridad: negative - Predicción: negative -> BIEN
# Frase: ['house', 'great']
# 	Polaridad: negative - Predicción: positive -> MAL
# Frase: ['song', 'annoying']
# 	Polaridad: negative - Predicción: negative -> BIEN
# Frase: ['beer', 'good']
# 	Polaridad: positive - Predicción: positive -> BIEN
# Frase: ['enjoy', 'job']
# 	Polaridad: negative - Predicción: negative -> BIEN
# Frase: ['feel', 'amazing']
# 	Polaridad: positive - Predicción: positive -> BIEN
# Frase: ['gary', 'friend']
# 	Polaridad: positive - Predicción: positive -> BIEN
# Frase: ['cant', 'believe']
# 	Polaridad: negative - Predicción: negative -> BIEN

# %% [markdown]
# <hr>
#
#
# # Modelo
#
# * Veamos a continuación algunas características del modelo:
#
#
# * Podemo ver por ejemplo la probabilidad de que una frase pertenezca a una etiqueta (label):

# %%
prob_positive = classifier._label_probdist.prob('positive')
prob_negative =  classifier._label_probdist.prob('negative')
print ('-> P(positivo) = ' + str(prob_positive))
print ('-> P(negativo) = ' + str(prob_negative))
# Out:
# -> P(positivo) = 0.5
# -> P(negativo) = 0.5

# %% [markdown]
# * Otra cosa que podemos ver es como de relevante son las palabras que se han utilizado para construir el modelo en función de la etiqueta.
#
#
# * Vemos por ejemplo que si la palabra "good" aparece en una frase (*contains(good) = True*), esta frase tiene 3 veces más probabilidades de clasificarse como positiva que como negativa. Esta cálculo (según el código) lo hacen de la siguiente manera:
#
#
# $$positi : negati = \frac{P(good|positivo)}{P(good|negativo)}$$
#
# $$negati : positi = \frac{P(good|negativo)}{P(good|positivo)}$$

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#           contains(good) = True           positi : negati =      3.0 : 1.0
#           contains(feel) = True           positi : negati =      1.7 : 1.0
#           contains(view) = True           positi : negati =      1.7 : 1.0
#           contains(good) = False          negati : positi =      1.2 : 1.0
#        contains(amazing) = False          negati : positi =      1.1 : 1.0

# %% [markdown]
# * Podemos ver tambien como calcula el peso para determinar si una frase es positiva o negativa:

# %%
# Ejemplo POSITIVO
t = "I feel happy this morning"
print ('Predicción: ' + classifier.classify(extract_features(t.split())))
print (classifier.prob_classify(extract_features(t.split()))._prob_dict)
# Out:
# Predicción: positive
# {'positive': -0.15265308280208068, 'negative': -3.316091331221177}

# %%
# Ejemplo NEGATIVO
t = "I do not like that man"
print ('Predicción: ' + classifier.classify(extract_features(t.split())))
print (classifier.prob_classify(extract_features(t.split()))._prob_dict)
# Out:
# Predicción: negative
# {'positive': -2.8112705203211075, 'negative': -0.221740853587729}

# %% [markdown]
# * Por último podemos ver la probabilidad de que una frase se clasifique como positiva o negativa en función de que aparezca o no una determinada palabra:

# %%
print("Probabilidad de que la frase sea NEGATIVA si APARECE la palabra 'good':")
print (classifier._feature_probdist[('negative', 'contains(good)')].prob(True))

print("\nProbabilidad de que la frase sea POSITIVA si APARECE la palabra 'good':")
print (classifier._feature_probdist[('positive', 'contains(good)')].prob(True))

print("\nProbabilidad de que la frase sea NEGATIVA si NO APARECE la palabra 'good':")
print (classifier._feature_probdist[('negative', 'contains(good)')].prob(False))

print("\nProbabilidad de que la frase sea POSITIVA si NO APARECE la palabra 'good':")
print (classifier._feature_probdist[('positive', 'contains(good)')].prob(False))
# Out:
# Probabilidad de que la frase sea NEGATIVA si APARECE la palabra 'good':
# 0.07142857142857142
#
# Probabilidad de que la frase sea POSITIVA si APARECE la palabra 'good':
# 0.21428571428571427
#
# Probabilidad de que la frase sea NEGATIVA si NO APARECE la palabra 'good':
# 0.9285714285714286
#
# Probabilidad de que la frase sea POSITIVA si NO APARECE la palabra 'good':
# 0.7857142857142857

# %% [markdown]
# # 04 - Clasificación de textos con Scikit-Learn
#
# * En este notebook vamos a ver como clasificar una serie de Tweets en Ingles sobre críticas a los productos de Apple.
#
#
# * Estos tweets estan clasificados como: *positivos*, *neutros* o *negativos*
#
#
# * El este notebook realizaremos los siguientes pasos:
#
#     1. Carga de los datos (tweets)
#     2. Normalización (en ingles) de los tweets
#     3. Creacción de la Bolsa de Palabras
#     4. Particionado de Datos
#     5. Creacción de modelos
#         - Multinomial Naive Bayes
#         - Bernoulli Naive Bayes
#         - Regresion Logistica
#         - Support Vector Machine
#         - Random Forest <sup>(*)Meta-Modelo</sup>
#     6. Evaluación de los modelos

# %% [markdown]
# <hr>
#
#
# ## Carga de Datos
#
#
# * El primer paso que vamos a realizar es el de cargar los datos. Para ello ***leeremos el csv con pandas*** (pasandolo a un dataframe) y posteriormente lo transformaremos en una lista de tuplas (*tweets*) donde cada tupla esta formada por:
#     - **Posición 0**: Tweet
#     - **Posición 1**: Polaridad (Positivo | Neutro | Negativo)

# %%
import pandas as pd
tweets_file = 'files/Apple_Tweets.csv'
df = pd.read_csv(tweets_file, header=None)
tweets = [tuple(x) for x in df.values]
print('Número de Tweets Cargados: {num}'.format(num=len(tweets)))
# Out:
# Número de Tweets Cargados: 3804

# %% [markdown]
# <hr>
#
#
# ## Normalización
#
# * Para este ejemplo haremos uso de ***spaCy***, pero en este caso tenemos que utilizar (e importar) el modelo para Inglés.
#
#
# ```
# >> python3 -m spacy download en_core_web_sm
# ```
#
#
# <img src="./imgs/010_spacy_en_download.png" style="width: 600px;"/>
#
#
# * Para ***normalizar*** los tweets realizaremos las siguientes acciones:
#     1. Pasamos las frases a minúsculas.
#     2. Eliminamos los signos de puntuación.
#     3. Eliminamos las palabras con menos de 3 caracteres.
#     4. Eliminamos las Stop-Words.
#     5. Eliminamos las palabras que empiecen por '@' o 'http'.
#     6. Pasamos la palabra a su lema
#
#
# * Todos estos pasos los vamos a realizar en una misma función.
#
#
# * ***NOTA***: *De cara a la normalización de textos se pueden realizar más acciones que las que vamos a realizar, pero con estas serán más que suficientes para realizar un ejercicio con fines didácticos*

# %%
# !pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.2.4-cp39-cp39-macosx_10_9_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 3.6 MB/s eta 0:00:01
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.9 MB/s eta 0:00:011
# Requirement already satisfied: jinja2 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.11.3)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp39-cp39-macosx_10_9_x86_64.whl (32 kB)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.3-cp39-cp39-macosx_10_9_x86_64.whl (457 kB)
#      |████████████████████████████████| 457 kB 3.6 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.7-cp39-cp39-macosx_10_9_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 5.0 MB/s eta 0:00:01
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp39-cp39-macosx_10_9_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy) (58.0.4)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.15-cp39-cp39-macosx_10_9_x86_64.whl (639 kB)
#      |████████████████████████████████| 639 kB 2.4 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.6-cp39-cp39-macosx_10_9_x86_64.whl (18 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy) (21.0)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: click<8.1.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy) (8.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.26.0)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp39-cp39-macosx_10_9_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 3.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.22.3)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 4.5 MB/s eta 0:00:01
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.4)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.8 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy
# Successfully installed blis-0.7.7 catalogue-2.0.7 cymem-2.0.6 langcodes-3.3.0 murmurhash-1.0.6 pathy-0.6.1 preshed-3.0.6 pydantic-1.8.2 smart-open-5.2.1 spacy-3.2.4 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.3 thinc-8.0.15 typer-0.4.1 wasabi-0.9.1

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 4.6 MB/s eta 0:00:01    |████                            | 1.8 MB 1.4 MB/s eta 0:00:09
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from en-core-web-sm==3.2.0) (3.2.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: click<8.1.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.15)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.26.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.1)
# Requirement already satisfied: jinja2 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.22.3)
# Requirement already satisfied: setuptools in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.3)
# Requirement already satisfied: pathy>=0.3.5 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/carlosograndetcaballero/opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

from tqdm import tqdm

nlp = spacy.load('en_core_web_sm')

# %%
# Divido los datos en dos listas 
#     X: los tweets
#     y: target (polaridad)

X = [doc[0] for doc in tweets]
y = [doc[1] for doc in tweets]

def normalize(sentenses):
    """normalizamos la lista de frases y devolvemos la misma lista de frases normalizada"""
    for index, sentense in enumerate(tqdm(sentenses)):
        sentense = nlp(sentense.lower()) # Paso la frase a minúsculas y a un objeto de la clase Doc de Spacy
        sentenses[index] = " ".join([word.lemma_ for word in sentense if (not word.is_punct)
                                     and (len(word.text) > 2) and (not word.is_stop) 
                                     and (not word.text.startswith('@')) and (not word.text.startswith('http'))])
    return sentenses

# Normalizamos las frases
X = normalize(X)
# Out:
# 100%|██████████████████████████████████████| 3804/3804 [00:17<00:00, 217.12it/s]

# %%
X
# Out:
# ['protester stage diein protest store nyc anger misplace retweet agree',
#  'apple intraday comment update range premium user aapl stockaction trading stock mkt',
#  'io app 2014 name elevate brain training iphone app',
#  'shit',
#  'founder attack boss ridiculous comment ad',
#  'evidence factcheckthis',
#  'educate',
#  'hard reach buy suicide squad comic_strip apple store turkey',
#  'delete music customer ipod',
#  'apple intraday comment update range premium user aapl stockaction trading stock mkt',
#  'studio 45,000 outlet computer need battery future',
#  'apple great business aapl investwall aapl',
#  'dear love iphone plus lot great achievement iphone reboot day fail',
#  'survey feedback iwatch positioning fashion accessory geek centric gadget',
#  'similar cloud backup picture onlinefootprint modicumofprudence',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'fuck make shit product',
#  'try turn problem',
#  'macbook pro annoying asus windows computer freezing laggy etc excellence',
#  'speak wearable new chargehr amp iphone want eat latke run place tl_chat',
#  'forbe whoop plaintiff apple tell court ipod owner class represent aapl',
#  'thank way call facetime call ability device seamlessly',
#  'mkt final aapl putcallratio monday december 2014',
#  'julian robertson bullish apple inc aapl',
#  'apple intraday comment update range premium user aapl stockaction trading stock mkt',
#  'new problem airport boarding pass phone hold scanner security applepay credit card take screen',
#  'help mac memory clear ask password old',
#  'ask use voice attribute dude ace vocal clone',
#  'fuck fuck hate',
#  'apple want commute easy accord new patent aapl',
#  'studio 45,000 outlet computer need battery future',
#  'need help apple iphone6 amp iphone6plus checkitout',
#  'invest terabyte storage',
#  'ceo warn wearable maker tech need productivity novelty like siri \r\n\r\n',
#  'gva lounge sight mac pcs undetermined number ipxs aapl',
#  'afp request apple reveal warrant pushback tax evader rip aussie',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'yeah monarchywpb sticker ride boommovement',
#  'afternoon tea ipadair2 touchpoint reward visit info',
#  'drain battery fix',
#  '.@apple ceo visit',
#  'promoproduct supplier carry brandable compliant adapter headsaregoingtoroll',
#  'new sony',
#  'apple pay service lead price target upgrade apple inc aapl aapl',
#  'studio 45,000 outlet computer need battery future',
#  'go canal street knockoff cmonman pay lightning cord',
#  'excited name app store good 2014 list year apple',
#  'gold macbook',
#  'studio 45,000 outlet computer need battery future',
#  'hey teach people use pay',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'good iphone app year accord apple monday december',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'make smart elevate app year congratulation team',
#  'final aapl putcallratio monday december 2014 hamzei',
#  'game trader play market liquidity hft darkpool stock trading algorithm aapl',
#  'studio 45,000 outlet computer need battery future',
#  'cool cool bait switch pay upgrade server free upgd 10.10.1',
#  '.@apple macmail yosemite give hard time alternative email program yosemiteproblem',
#  '.@apple make hard spend money app functionality soon disappear today menu stop',
#  'congrat mary sotos green power leadership award',
#  'need battery game get time charge phone furstrate annoyed charge',
#  'hoe',
#  'music library sync new music etc itune tell sync complete new upload fix frustrating',
#  'apple make bad charger genius say wrap electrical tape wonder jony think',
#  'amp delete music customer ipod tell',
#  'studio 45,000 outlet computer need battery future',
#  'apple inc aapl price target ep estimate raise bmo',
#  'want android apple torrent?@apple',
#  'iphone ipad game 2014 apple name monument valley amp three tuesday december',
#  'apple intraday comment pre opening premium user aapl stockaction trading stock mkt',
#  'apple great business aapl',
#  'amazing customer service today utc store work form store hour tbjapodcast',
#  'aww look tht lot work guy good luck',
#  'kantar apple track record quarter iphone6 sale bump wednesday december',
#  'iphone battery life take piss sort iphone iphone apple',
#  'spy pair m50s good work',
#  'product line compete iphone6 vs. ipad need ipad long',
#  'dominate commerce device grab market share',
#  'try turn problem',
#  'apple iphone iphone4 iphone4problem fuck help work apple fuck help job cunt',
#  'idk happend',
#  'computer slow right make want shoot god dam mac hav deal',
#  'good iphone app year accord',
#  'computer science education week come check code opportunity help',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'apple recent pullback buy opportunity aapl',
#  'know fix xcode simulator try complete reinstall io',
#  'real tired charger break month',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'twitter',
#  'fuck charger like shit',
#  'apple warm social medium apple hire social media guru l.a finally tweet?her',
#  'thank good coverage nofear',
#  'apple hedge bet small iphone aapl',
#  'aapl ios8 browser share',
#  'bad idea bring tap tweet function guy',
#  '.@apple ban school yik yak app itunes app store app anonymous bullying amp threat',
#  'enjoy introduction connected launch event amazing edtech leader room txe',
#  'apple important stock earth aapl',
#  'go come',
#  'studio 45,000 outlet computer need battery future',
#  'blackberry want iphone pay \r\n  bbry bbry blackberry iphone aapl aapl',
#  'iupdate new need dun year ago web form phone ironic req support ie8',
#  'asshole shit',
#  'report apple hire fashionista help flog watch aapl aapl',
#  'apple build major new r&amp;d facility japan prime minister reveal aapl aapl',
#  'tim cook show apple watch chinese internet official discuss security issue aapl',
#  'translate app success story taus member global',
#  'lol quicktime movs',
#  'apple inc google inc battle tech giant aapl',
#  'big difference mac yep stick mac apple',
#  'studio 45,000 outlet computer need battery future',
#  'new inch iphone report reason apple aapl aapl',
#  'office today remotesupport techlife',
#  'studio 45,000 outlet computer need battery future',
#  'jmp raise apple price target 130 150 reason jmp aapl stock wallstreet',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'studio 45,000 outlet computer need battery future',
#  'aapl alabama anti discrimination bill name apple ceo tim cook...http://t.co/j6hgjmjbzd',
#  'apple intraday comment pre opening premium user aapl stockaction trading stock mkt',
#  'result mobility pilothouse program loyal customer',
#  'aapl apple donate portion profit fight aids...http://t.co/br05n1u3qr',
#  'bloombergtv stevejob testimony play key role ipod trial aapl',
#  'apple macbook 949.86 tech',
#  'app ipodtouch5thgen',
#  'offensive thing lack trashcan emoji stop discrimination',
#  'major crisis avoid guy able restore daughter iphone great service thank 5starservice',
#  'tell feel',
#  'stop replace iphone unit defect scratch phone mean drop',
#  'live streaming blow',
#  'jmp raise apple inc price target 150 exceptionally strong demand aapl',
#  'phone keep fucking freeze',
#  'apple iphone lead time long previous model aapl aapl',
#  'sit home friday night wait invitation join dev team look phone day',
#  'apple raise barclay 140.00 overweight rating aapl aapl',
#  'iphone come rareearth',
#  'thisn#yosemite update stress macbookpro',
#  'aapl expect user like small screen iphone mini reportedly way aapl',
#  '118 tomorrow aapl',
#  'frustrate unsuccessfully try fix outgoing smtp configuration lt;3 unacceptable yosemiteproblem apple help',
#  'apple intraday comment update premium user aapl stockaction trading stock mkt',
#  'official williamsburg long hip anymore',
#  'thing happen',
#  'definition easy warp thank useless corporate speak',
#  'daring fireball transmit io icloud drive',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'sign utterly break wifi driver air sit lap desperate read email android phone',
#  'gtat creditor want question apple jeff williams aapl aapl',
#  'aapl ipad mini sony xperia tablet compact step aside sony apple s...http://t.co/85qgeih7lo',
#  'fuck phone search service complete day',
#  'mkt final aapl putcallratio tuesday december 2014',
#  'damn wish iphone imessage money damn damm damn',
#  'thank disturb feature',
#  '.@apple ceo visit',
#  'dear bad idea fix',
#  'power cord problem- warranty say fine replace',
#  'sooooo annoy restore lose voice mail need thank lot',
#  'ischool education',
#  'rumor roundup crescentgate gate aapl aapl',
#  'store nyc honor travel',
#  'tech stock soar 2015 motley fool goog aapl',
#  'apple raise canaccord genuity 135.00 buy rating aapl aapl',
#  'aapl apple stock price plummeting time sell bit',
#  'aapl fantastic investment future aapl beat aapl',
#  'consider ad feed facebook privacy change think tim cook spot',
#  'barclay raise aapl price target 140 aapl aapl',
#  'footage apple-1 computer run computerhistory',
#  'total nightmare big slice cake',
#  'apple launch inch iphone year report aapl aapl',
#  'watch sdk monetizaton download watchkit soon possible',
#  'downgrade iphone obviously understand extra battery life morning dead',
#  'year goal apple free tired',
#  'hey nvm restart phone work',
#  'need eye roll emoji pronto',
#  'reason iphone imessage bruh well battery',
#  'studio 45,000 outlet computer need battery future',
#  'know smartwatch old fashioned clock face grandma need watch',
#  'good think go compete dropbox etc bad sign like macpro std 250',
#  'face',
#  'notice app instead free change alleged misleading labeling',
#  'studio 45,000 outlet computer need battery future',
#  'degree nice weather',
#  'aapl carl icahn cause new private equity bubble?',
#  'touch screen macbook',
#  'mkt final aapl putcallratio wednesday december 2014',
#  'delete unwanted photo time want recently delete folder',
#  'studio 45,000 outlet computer need battery future',
#  'apple patent iphone drop protection mechanism change device tuesday december',
#  'sketchy rumor claim apple plan new inch iphone 2015 aapl',
#  'patent active fall protection system shift iphone midair technology fyi',
#  'studio 45,000 outlet computer need battery future',
#  'big spending consumer cyber monday \r\n\r\n cybermonday paypal apple aapl ebay walmart wmt sale',
#  'cnbctv cramer apple real competition aapl',
#  'love phone thank base god',
#  'apple antitrust case hang balance antitrust wow ipod',
#  'bad thing update software computer update trash',
#  'come charger case hurr',
#  'day access passwd apple work new app calendar ecosystem achille',
#  'thing know today include hoard iphone6',
#  'hey love applecare low hold music awful prefer hear tip apple gear well use hold time',
#  'def got like watch',
#  'star analyst alex gauna jmp security rate aapl buy alex success rate nasdaq stock aapl',
#  'confirm bose speaker return apple store removal early year aapl beatselectronic',
#  'app ipodtouch5thgen',
#  'hah defend understand internet',
#  'apple tentatively approve plan expand reseller network india 500 new store mac blog aapl',
#  'aapl android phone dominate 2018 io phone revenue',
#  'aapl apple court billion line...http://t.co/mduqi14xqk',
#  'ayyy fourth phone charger week break today fuck',
#  'studio 45,000 outlet computer need battery future',
#  '.@mcdonalds share slice iphone6 lover',
#  'nofear',
#  'shipping estimate inch retina imac improve week mac blog aapl',
#  'security firm issue cheery 2015 prediction pay attract attack',
#  'pay taxis country',
#  'twdancecenter urbannutcracker store boylston 6.30pm enjoy krumping meet director amp',
#  '.@google unseat u.s classroom chromebook beat ipad',
#  'average mac user face malware threat year remain minor target mac blog aapl',
#  'ipod change order song playlist listen fly fuck okay',
#  'autocorrect change muslim awesome okay',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'think want watch',
#  'evidence apple inc need refresh apple aapl',
#  'flip great apple iphone smash detect saturday',
#  'window lappy work half price alternative',
#  'hey guy charger last fucking week',
#  'get iphone iphone6 iphone',
#  'studio 45,000 outlet computer need battery future',
#  'computer turn help',
#  'take month iphone6 plus king phablet aapl',
#  'studio 45,000 outlet computer need battery future',
#  'remove photo upload cover refund purchase base feature',
#  'autocorrect change muslim awesome okay',
#  'battery minute usage fix',
#  'mfn international trade key issue ebook appellate case say',
#  'apple watch top search engine list good wearable tech aapl iwatch applewatch',
#  'studio 45,000 outlet computer need battery future',
#  'apple inc sell million apple watch 2015 aapl',
#  'snapchat',
#  'hey look weird',
#  'wrap charger begin smoke well apple',
#  '.@panic inconsistency overall weirdness control appstore archive previous version easy downgrade',
#  'iphone release date need feature aapl aapl',
#  'dinner night leave computer charge fire happen house applecordfire',
#  'god dammit fuck',
#  'head store today yike yay dayoffdutie',
#  'apple fade away streaming video player market vod stream',
#  'studio 45,000 outlet computer need battery future',
#  'try launch info ahead time telco marketing team nightmare thank ecomchat',
#  'good buy cut apple inc ipad price boost sale aapl ipad',
#  'take marketing convert shopper buyer amp create total sense experience',
#  'apple dilemma apple aapl aapl',
#  'chromebooks overtake apple ipad u.s education market chromebook ipad',
#  'smartphone tablet home automation hub wireless protocol beat wifi bluetooth homekit flic',
#  'got love autocorrect iphone make person illiterate fuck quit guess let correct',
#  'yahootech admit year remove non itunes music ipod',
#  'apple bear fat payout stock swoon second plunge aapl aapl',
#  'expect spanish inquisition aapl',
#  'news raise bill pre 164.5 bill cash good time valley wait',
#  'apple dominate mobile online shopping percent aapl',
#  'tim cook 100 billion mistake aapl',
#  'osx build keylogger provide',
#  'game bitch try tonight gam night gawd',
#  'learn apple ipad air 128 gold',
#  'block trade detect aapl',
#  "split valley user datum say totally amp say,'like titianfight",
#  'rumor surface apple iphone6s iphone7 2015 wednesday december',
#  'dear \r\n\r\n fault pos macbook airquote pro fast port drop pro future toycomputer',
#  'note mail trouble send update fix mail send useful',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'apple plan launch iphone mini version 2015 aapl aapl',
#  'tell update stop capitalize',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'harry potter emoji work',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'news apple patent prevent crack iphone apple award patent gravity defy',
#  'io app 2014 name elevate brain training iphone app',
#  'excited name app store good 2014 list year apple',
#  'apple plan launch iphone mini version 2015 aapl aapl',
#  'iphone plus availability wait time update aapl aapl',
#  'obviously left multi talented super successful gay business agenda',
#  'sunrise northamptonshire northampton wow sunrise morning iphone6 apple sun',
#  'talk town crescentgate',
#  'lose factor recovery key permanently lock apple aapl',
#  'get nigga turban sista headscarf',
#  'apple inc samsung group continue fight sub-$1 billion award loom aapl aapl',
#  'week iphone push currently',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'studio 45,000 outlet computer need battery future',
#  'hey keyboard phone sort drunk morning send help pls thx',
#  'nice iphone get pity happen',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'sunrise northamptonshire northampton wow sunrise morning iphone6 apple sun',
#  'aapl market cap pass 700 billion tablet sale slump',
#  'programming language code analysis web tech nerdup',
#  'apple price target rise 140 apple aapl',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'harry potter emoji work',
#  'hey fuck phone speaker long work',
#  'win digital makeover giveaway 1000 gc,#ipad macbook pin',
#  'annoying stuff right time',
#  'iflipphone',
#  'apple 115 fit 8.4 increase earning use 2014q3 eps=$1.42 free io app donkey stock aapl',
#  'stevejob email want smear competitor hacker aapl',
#  'apple delete rival music ipod court hear apple itune ipod',
#  'innovation die steve job apple macintosh aapl',
#  'love iphone6 mobilephone',
#  'update yosemite machine painfully slow thank',
#  'poor try ipad macbook look useful commercial close power pro',
#  'foxconn robot prove unsuitable iphone assembly update version work aapl',
#  'bbc news evidence late steve job music trial aapl \r\n\r\n',
#  'photo love io love ios8 nocrop iphone young phone screen capturescream boy',
#  'yosemite ruin wifi',
#  'innovation sector large multipli effect come job employ 13,000 create 70,000 indirect job',
#  'roll webgl ios8 month ago overtake webgl support level',
#  'hey battery iphone drop like cock gay porn xvideo main page fix shit',
#  'announce app 2014 favourite app list appstore2014',
#  'watch steve wozniak use iphone6 magically unlock hotel room woz',
#  'charger suck',
#  'ios8 delete contact actually delete fml fuck',
#  'studio 45,000 outlet computer need battery future',
#  'macbook pro non retina startup macbook macbookpro startup hipst',
#  'apple need china love apple watch aapl aapl',
#  'check macbook pro 15.4 retina 2.6 ghz 500 ssd mid 2012 650 2magsafe apple',
#  'apple pay add issuer l&amp;n federal credit union credit union m&amp;t bank aapl aapl',
#  'studio 45,000 outlet computer need battery future',
#  'apple warm social medium apple hire social media guru l.a fin startup nyc',
#  'hines staff newly issue connect macbook ipad mini txed txed',
#  'happy',
#  'time buy dip apple inc stock aapl aapl',
#  'twitter problem',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'studio 45,000 outlet computer need battery future',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'hey catch fucking maverick wave iphone think surfsupsamsung',
#  'lack equal access technology place student minority disadvantage education great equalizer txe',
#  'studio 45,000 outlet computer need battery future',
#  'aapl steve job defend apple tape deposition...http://t.co/7oxigddequ',
#  'get powerbeats2 repair shoutout',
#  'block trade detect aapl',
#  'fuck recently delete photo album',
#  'legendary designer give young designer simple rule follow',
#  'robot fabricando iphone ipad pro apple watch apple sunday december',
#  'displeased lack bdsm themed emoji',
#  'harry potter emoji work',
#  'apple enter era security fear mongering security vendor aapl aapl',
#  'apple inc seo walk mystery aapl',
#  'studio 45,000 outlet computer need battery future',
#  'steve wozniak star upcoming reality focus futuristic tech mac blog aapl',
#  'elgato launch thunderbolt dock resolution support mac blog aapl',
#  'force people use vpn build ios8 button work ff like want apple nsa data collection service',
#  'new item come product start tweak',
#  'overheard employee tell some1 use capital letter password cause easy remember applefail',
#  "dear lovin' heck navigation arrow itune store use software",
#  'aapl stock mini flash crash today money morning analyst suggest widel',
#  'apple green company america energy efficiency',
#  'cnbctv day apple antitrust trial aapl',
#  'apple important stock earth apple inc aapl seek alpha',
#  'important apple developer world need people invent stuff tim cook ceo',
#  'logjn amp reorder tweet 2step auth share password amp say malware',
#  'final aapl putcallratio monday december 2014',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'iphone alarm fail work miss bonus point class sooooo annoyed',
#  '2015 year biometric wearable cryptocurrency stream aapl aapl',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'thestreet google major headache go 2015 apple facebook aapl goog',
#  'come aapl shit',
#  '45,000 foot keeeppppp flyinggggg',
#  'fuck',
#  'fuck goddamn stupid fuck justsayin itune',
#  'learn apple ipad mini smart cover green',
#  '.@apple market share smartphone market drive iphone great sale apple store',
#  'apple intraday comment update range premium user aapl stockaction trading stock mkt',
#  'apple release io 8.1.2 fix disappear ringtone issue aapl',
#  'aapl apple share repurchase benefit shareholder billion',
#  'go sell stuff provide visibility order system',
#  'apple intraday comment update premium user aapl stockaction trading stock mkt',
#  'mark word wild away iphone bring iphone ultimate form factor welcome iphone mini',
#  'happen',
#  'justice department cite 18th century federal law unlock iphone',
#  'immune bug like like people spend time choosewisely',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'apple inc catch iphone supply lag demand aapl',
#  'aapl apple inc aapl fall week monday morning drop...http://t.co/ut65kwzukc',
#  'studio 45,000 outlet computer need battery future',
#  'explore apple rumour 2015 apple2015 techireland',
#  'aapl buy reiterate target raise 135 canaccord genuity aapl brief explanation aapl',
#  'apple inc explosive quarter jmp analyst aapl',
#  'harry potter emoji work',
#  'thank think upgrading',
#  'big thing wireless earbud aka earplug sound soundplug',
#  'ipod lawsuit reveal unseen steve job video',
#  'sound like need upgrade iphone spacious purse hold item tl_chat',
#  "aapl:'fast money recap energy company ebb flow oil prices...http://t.co/qrwllgclk6",
#  'belong employeediscount',
#  'thank push yosemite bad slow clunky cantgoback misssnowleopard whathappene',
#  'holiday giveaway ensure stay touch brand like',
#  'watcha soldering iron woz computer swap cap',
#  'alarm set ringer refuse work fuck',
#  'follow pls',
#  'nasdaq100 recent market exit sell aapl long 10.49 gain day aapl forex trading stock',
#  'tre',
#  'try buy charger protest nyc wecantbreathe 5thave apple store fifth avenue',
#  'gorgeous iphone app surprising design amazing visual bgr aapl',
#  'studio 45,000 outlet computer need battery future',
#  'aapl horseman nasdaq 100 apple microsoft gilead scie...http://t.co/cdvozfgsbx',
#  'shit',
#  'good get new shiny mac handy',
#  'save ton money buy iphone aapl',
#  'merge multiple apple fail',
#  'promoproduct supplier carry brandable compliant adapter headsaregoingtoroll',
#  'studio 45,000 outlet computer need battery future',
#  'love support hourofcode workshop',
#  'iscuba 360 degree camera rig cloud mobile game surface imask underwaterwearable cardboard pivot',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'twitter',
#  'try turn problem',
#  'recent apple inc lawsuit hurt share price aapl',
#  'problem blame anybody like join roster',
#  'ditch tomtom license map datum',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'aapl apple iphone lead time long previous models...http://t.co/2bgo33v309',
#  'final aapl putcallratio wednesday december 2014',
#  'apple nasdaq aapl participate world aids day campaign apple aapl campaign',
#  'bloombergtv apple exec sentence year prison fraud aapl',
#  'mistake it´s time replace fix 2011 macbook pro graphic failure mbp2011',
#  'get patent 2prevent crack screen rotate fall iphone bigdocc',
#  'studio 45,000 outlet computer need battery future',
#  'fuck',
#  'studio 45,000 outlet computer need battery future',
#  'play game',
#  'aapl unsubsidized smartphone 25...http://t.co/frqhiwnfp5',
#  'hey software update ipad open webpage idea',
#  'hopefully bday believe second dear',
#  'month store visit call iphone receive text non customer fail',
#  'great crack screen amp die battery think trade new',
#  'apple raise citigroup inc 135.00 aapl aapl',
#  'yes love stuff work thank',
#  'block trade detect aapl',
#  'ask friend',
#  'mark zuckerberg take shoot apple aapl',
#  'well charger fam cheap cuz get job',
#  'shopping pay receive good flight far well custserv',
#  'iphone autocorrected believe beiber hard guy need',
#  'charger weak needa iphone charger otterboxe cord',
#  'laptop battery go straight',
#  'hide gray controller dvd player heck',
#  'reply livingthedream ~ari',
#  'thank',
#  'studio 45,000 outlet computer need battery future',
#  'apple hire map engineer work improved community crowdsourcing siri passbook integration aapl',
#  'morph action police praetorian guard work unaware rich',
#  'dear write give mean want word give word typo',
#  '2014 canadian flag emoji keyboard',
#  'steal apple',
#  'help store rep tell itune backup save multiple backup back phone old backup go',
#  'studio 45,000 outlet computer need battery future',
#  'world murder facetime thank innovation',
#  'obsession',
#  'dear replace phone battery suck',
#  'studio 45,000 outlet computer need battery future',
#  'cnbctv drive apple aapl',
#  'tweet nando phone put cap like iphone know favourite restaurant good phone',
#  'thank little troll put option close right save tab legend',
#  'apple inc catch iphone supply lag demand aapl',
#  'fact itune update make anal reset play count mosttttt',
#  'horrible packaging shipping shame',
#  'walk anna pick iphone 128 address',
#  "remind tomorrow f'e tell update want install actually",
#  'apple corporate raider sell weak product stop work weeks&amp;apple get warranty claim dampness',
#  'studio 45,000 outlet computer need battery future',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'studio 45,000 outlet computer need battery future',
#  'apple name 10th disruptive idea past year businessweek aapl aapl',
#  'studio 45,000 outlet computer need battery future',
#  'apple dec trading daily profit 1.57 weekly profit 18.36 aapl stockaction trading stock mkt  \r\n',
#  'apple iphone gain significant share japan germany great britain aapl aapl',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'otter emoji',
#  'aapl samsung ask appeal court throw 930 million damage apple',
#  'condosenior say need supply condo dedicated tech issue iphone imac ipad warrant tech eat',
#  'wait okay yeah actually burn',
#  'thank fix swift sourcekit crash xcode life well',
#  'aapl apple inc facebook clash wrong...http://t.co/uuvn8tkrrs',
#  'foreign currency exchange headwind apple aapl aapl',
#  'studio 45,000 outlet computer need battery future',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'stevejob predict future ecommerce 1996 get exactly right aapl',
#  'detail apple inc ipad mini reveal aapl',
#  'studio 45,000 outlet computer need battery future',
#  'strategic step time trading stock future forex trader baba aapl gpro eem esignal',
#  'hope use glass new store williamsburg \r\n\r\n afraid sikrikim tzimerman break',
#  'studio 45,000 outlet computer need battery future',
#  'logic board completely replace warranty free sure',
#  'osx build keylogger provide',
#  'phone automatically reason kinda dumb thank',
#  'yay customer support super nice helpful imessage verify',
#  'special education staff work hard behalf student disability ed1426',
#  'guru fund manager hold apple aapl',
#  'harry potter emoji work',
#  'fix phone',
#  'apple important stock earth aapl',
#  'call wit amanda end fix urself',
#  'fight fight fight',
#  'bring classicipod cantbelieveitsgone',
#  'strike somewhat stupid send brand new iphone late software restore old stuff',
#  'year loss apple finally claw market share android aapl aapl',
#  'gosh darnit know cloud',
#  'setting use app location app instead',
#  'love support hourofcode workshop',
#  'studio 45,000 outlet computer need battery future',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'archetype figure product intuitive',
#  'iphone fuck thank great help new iphone',
#  'mother',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'thinking upgrade yosemite think twice asmsg',
#  'need eye roll emoji pronto',
#  'ahhhh store course',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'great piece amp new red app store profit exclusive content',
#  'ipad mini time startup ipadmini ipad macbook macbookpro startup hipst unbox',
#  'studio 45,000 outlet computer need battery future',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'thank preview smartwatch fitnesstracker quantifiedself iot',
#  'iphone plus apple sprint give bread trash ass phone fuck up',
#  'fuck',
#  'apple inc weekly roundup facebook ad amp ipad aapl',
#  'kantar worldpanel iphone sale october huge aapl aapl',
#  'meet elevate apple pick good iphone app year monday december',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'apple open new research site japan aapl aapl',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'massive mobile tech company like excite wearable invest million \r\n\r\n',
#  'man chromecast pretty sweet',
#  'cnbctv buy apple pullback aapl',
#  'sorry go hope fix real pain apple care cover free',
#  'wow family guy simpson dowmload old update need update wait',
#  'big fan watch',
#  'studio 45,000 outlet computer need battery future',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  '.@apple kill genius bar reservation online mac apple store',
#  'wish prosecute admin violation privacy criminal search seizure',
#  'patent number patent 8,903,519',
#  'bose product reportedly set return apple store shelf early week aapl jimmyiovine',
#  'kid parent need monitor power cord daily sure safe applecordfire',
#  'studio 45,000 outlet computer need battery future',
#  'youtube apple app update streamlined interface video advertisement aapl',
#  'fix',
#  'studio 45,000 outlet computer need battery future',
#  'charger suck ass love break',
#  'thing buy iphone come replace battery month',
#  'new phone christmas spreadsomejoy',
#  'tree know maybe cop cig deal senseless',
#  'ciosynergy ciolosangele give away tv visit',
#  'apple ceo tim cook come gay',
#  'enjoy garageband garageband',
#  'watch',
#  'studio 45,000 outlet computer need battery future',
#  'hang loose',
#  'final aapl putcallratio monday december 2014',
#  'apple aapl plan launch iphone6 mini version 2015 monday december',
#  'awesome invent peanut butter sandwich technology phone',
#  'yeah thing inspire apple course apple++ 2002 tvad',
#  'interesting job wth crowdsourcing tip map community client software engineer',
#  'phone die let happen',
#  'harry potter emoji work',
#  'ub see apple inc aapl iphone sale aapl',
#  'conclusion good client service',
#  'dashlane introduce password changer allow user change multiple password click mac blog aapl',
#  'estimate trillion market cap apple far fetch fundamental algorithmic analysis aapl',
#  'fuck',
#  'similar exist app call cardio guru interestingly maybe apple notice',
#  'hour hold customer service try figure messup',
#  'product write paper \r\n\r\n photo credit iphone',
#  'robot fabricando iphone ipad pro apple watch apple sunday december',
#  'literally go iphone cord little year fix suck',
#  'know iphone die like',
#  'apple ceo tim cook come gay',
#  'genius bar@apple store helpful aapl staff help genius comp wke',
#  'love support hourofcode workshop',
#  'go fix map app navigation suck face switch google map',
#  'apple continue beef digital audio expertise hire dana massie audience aapl aapl',
#  'apple sale top chromecast aapl push apple inc aapl fuss',
#  'iwatch change face watch applenews iwatch gadget',
#  'well design iphone app world accord',
#  'studio 45,000 outlet computer need battery future',
#  'week replace harddrive ridiculous homework',
#  'apple bear pay contract double amid drop aapl',
#  'enterprise developer agreement wait 719 seven nineteen page',
#  'learn apple ipad mini smart cover pink md968ll',
#  'apple dec total trading daily profit 2.78 aapl stockaction trading stock mkt',
#  'wrong',
#  'tablet damn right',
#  'aapl invest tsla increase r&amp;d plus increase production multi fold car suv 2015 amp china supercharge',
#  'disrespectful',
#  'dear',
#  'studio 45,000 outlet computer need battery future',
#  'need texas flag emoji',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'apple warm social medium apple hire social media guru l.a finally tweet?her',
#  'update apple healthkit see early adoption aapl',
#  'apple loop iphone6s rumor steve job garage myth iphone speculation saturday december',
#  '.@apple reportedly hire fashion focus staff physical store ftdaily fashiontech',
#  'brass band store broadway winterseve nyc',
#  'proof use product freak mail show search file finder \r\n\r\n nut kick',
#  'aapl google tops apple //feeds.foxbusiness.com/~r foxbusiness video/~3/-dbuio5m0_m/',
#  'hey album phone',
#  'need china love applewatch aapl wearable wearabletech apple',
#  'cnbctv apple exec stand aapl',
#  'studio 45,000 outlet computer need battery future',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'apple inc go trial anti trust charge today aapl',
#  'completely love iphone6 right play newphone amp dig day complete pizza',
#  'excited name app store good 2014 list year apple',
#  'bad idea bring tap tweet function guy',
#  'product shit break 24/7 ruin life',
#  'slow food movement metaphor platform strategy apple iphone ipad apple watch aapl',
#  'studio 45,000 outlet computer need battery future',
#  'good product boycott forever',
#  'date clone come',
#  'reason hate',
#  'seriously e hate new version itune spend hour try figure synch w/o delete',
#  'case accident download free app winnipeg',
#  'jmp security think apple inc go 150 time sell aapl',
#  'sync folder',
#  'computer sux fix',
#  '',
#  'difficult help product waste minute life online',
#  'alabama state representative anti discrimination bill tim cook aapl apple timcook',
#  'studio 45,000 outlet computer need battery future',
#  'life soon',
#  'god play forreal',
#  'order osx like network clone copy ideas?@appieofflciai',
#  'maybe stop whore sleep',
#  'studio 45,000 outlet computer need battery future',
#  'apple iphone plus retina imac ship time improve time holiday aapl aapl',
#  'aapl time start buy apple?',
#  'worry crash stop',
#  'plane amazing look cool yes need battery write list',
#  'job say apple take pain protect record contract stevejob aapl',
#  'want delete email turn',
#  'iphone6 plus availability wait time update apple store verizon sunday december',
#  'apple planning support 500 apple reseller india focus io aapl',
#  'aapl pale hoarse steve job defend apple videotape deposition ipod...http://t.co/snmpsx4tdo',
#  'howto import objective code bridge header file sdk swift',
#  'studio 45,000 outlet computer need battery future',
#  'fix problem good change logic board check apple genius',
#  'refusal application app store uphold australian federal court apple appeal',
#  'new iphone free apple share invest stock aapl',
#  'apple inc ceo donate 291k pennsylvania school district aapl',
#  'apple inc price close december 2014 114.9801 apple aapl',
#  'steve wozniak call legendary garage bit myth',
#  'thing know today include hoard iphone6',
#  'know suck store lock week preordere smh',
#  'alabama anti discrimination bill name',
#  'battery die long live apple sell new battery new iphone 500',
#  'studio 45,000 outlet computer need battery future',
#  'hey guy charger last fucking week',
#  'think happen hate day',
#  'want drop word book product employee start treat machine care aka stop drop',
#  'everybody track stuff usp great small package tracking',
#  '.@dell order laptop today try instead maybe rep kind instead behavior',
#  'realworld etnui magicleap spin collection dream thought discussion share',
#  'myth vs. reality time trading stock future forex trader aapl gpro esignal',
#  'studio 45,000 outlet computer need battery future',
#  'apple watch hackathon app challenge emerge aapl aapl',
#  'aapl apple store host free code workshop second annual hour code',
#  'love samsung kristen bell watch weekend new ad',
#  'caller able block product apple iphone6 iphone6plus',
#  'profit apple aapl option trade trading finance short bet hedge',
#  'studio 45,000 outlet computer need battery future',
#  'bored huh',
#  'turkey tday care appleemojissuck',
#  'new role require new hardware thankful',
#  'rich quick criminal capitalist steal client product apple technology',
#  'enjoy studio wireless beat',
#  'clear support rand paul 2016 case pigeonhole red blue like',
#  'haha switch',
#  'phone suck',
#  'final aapl putcallratio tuesday december 2014 hamzei',
#  'need ride drive mall today schedule appt mac daddy',
#  'studio 45,000 outlet computer need battery future',
#  'studio 45,000 outlet computer need battery future',
#  '.@apple want stop take vertical photo',
#  'honest great fanaticism turn equally great dislike',
#  'figure iphone randomly lose contact hour reason wth',
#  'wait ipod bubblews apple',
#  'phone suck',
#  'agree robust chocolate fire guard',
#  'computer slow',
#  'apple important stock earth aapl',
#  'need product like .@aviate company like .@blackberry amp .@apple need embrace customization quality theme',
#  'cash aapl cfd 110 113 inside hour brave',
#  '128 version',
#  'good iphone app 2014',
#  'studio 45,000 outlet computer need battery future',
#  'oop sorry applebee mean',
#  'buy phone use',
#  'got kid',
#  'thank amp postman work overtime',
#  'thx .@apple 2600 digital language new internet leader,10 cost diy .@googlenexus',
#  'ipad change way child learn classroom education tech',
#  'iphone6plus vs. galaxy note apple snatch away phablet thursday decem',
#  'studio 45,000 outlet computer need battery future',
#  'surprised talk look like flash crash aapl yesterday big range year largely ignore',
#  'homekit soon control home iphone aapl aapl',
#  'apple price target raise bmo capital see unfulfilled iphone demand push march quarter aapl aapl',
#  '',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'patent iphone drop protection mechanism end crackedscreen',
#  'fucking phone screen break want phone naked free',
#  'block trade detect aapl',
#  'charge ringtone let use thanksobama',
#  'forget apple iphone samsung galaxy humble flip phone frid',
#  'hope store arndale pass staff member staff visually impaired inspiration great work inawe welldone',
#  'steve wozniak call legendary garage bit myth',
#  'encourage marxist isis give order arrest marxist dupe trespass pantsupdontloot',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'tell tester gmail io app work tell tester',
#  'figure memory issue ipad bug new hidden folder store image',
#  'battery die',
#  'hell',
#  'studio 45,000 outlet computer need battery future',
#  'dear create middle finger emoji asap sincerely iphone user',
#  'dawn probably spend replace fray non function iphone cable spend iphone',
#  'apple raise jmp security 150.00 outperform rating aapl aapl',
#  'try thousand foot fly',
#  'way',
#  'like emoji look like',
#  'hey let facetime claire stop rude',
#  'prove',
#  'hey come saturday movie night fail appletv chuck guy wifegoingtosleep',
#  'apple patent idea stevejob hate aapl',
#  'apple aapl plan launch iphone6 mini version 2015 monday december',
#  'ayo think create video message option answer facetime leave video mail',
#  'fda clear smartphone connect thermometer store holiday',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'unfollow unlike tuesday unlike unfollow socialcleanuptuesday maybe antidrama',
#  'studio 45,000 outlet computer need battery future',
#  'need new emoji preferably brown people shxt like',
#  'ub increase apple iphone6 sale revenue ep friday december',
#  'iphone5s good mobile easy work wonderfull thank',
#  'apple inc profit margin continue upward aapl aapl',
#  'photo café mac check shady groove check techie frequent',
#  'walk work see trade bent ass iphone needa fix shit',
#  'big storage',
#  'playlist ipod add auto download album playlist shuffle hear',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'fan scramble ipod classic music player apple kill aapl \r\n\r\n',
#  'apple patent iphone drop protection mechanism change device tuesday december',
#  'ipod photo possible come end 10yrs battery charge',
#  'aapl:5 rocket stock buy december gain apple more...http://t.co/eg5xhxdll',
#  'hey battery iphone drop like cock gay porn xvideo main page fix shit',
#  'principle truth eddy cue talk fortune apple appeals book price fix judgment aapl',
#  'read apple iphone china unicom lead time aapl aapl',
#  'u.s government accept donation reduce national debt fact',
#  'store host free code workshop hourofcode 12/11/14 computerscience',
#  'hope amp io allow compact view 3rd party keyboard like swiftkey swype android',
#  'dream night downgrade iphone spend rest dream try figure shame',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'make smart elevate app year congratulation team',
#  'look especially decline sale look like aapl decide want samsung piece pie',
#  'fail poli sci fucking laptop sue',
#  'apple warm social medium apple hire social media guru l.a finally tweet?her',
#  'real cute sync music phone',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'wwa movie itune',
#  'studio 45,000 outlet computer need battery future',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'surprise explanation bend iphone',
#  'aapl abe say apple build technical center japan...http://t.co/deavv9aymk',
#  'host free code workshop store',
#  'studio 45,000 outlet computer need battery future',
#  'year old wizkid turn nab backing hollywood star',
#  'apple inc price close december 2014 115.95 apple aapl',
#  'harry potter emoji work',
#  'studio 45,000 outlet computer need battery future',
#  'iphone6 fall screen shatter like blow want additional 109 fix maybe product last',
#  'mark zuckerberg slams tim cook care customer aapl',
#  'sale iphone plus settle long run argument apple smartphone aapl aapl',
#  'apple inc iphone infringe chinese company patent aapl',
#  'cnbc fat finger aapl look day later',
#  'happen music delete music customer ipod',
#  'touch screen macbook',
#  'aapl apple delete music customer ipods...http://t.co/ieyvcmygav',
#  'company admire rock work mainly boss culture',
#  'iphone plus make large phone sale iphone lead ios device io blog aapl',
#  'patent system change position iphone mid air yay',
#  'cite constitution judge pass law violation separation power',
#  'get new iphone6 grow love bit bulky come iphone5 nice feel thank wait applewatch',
#  'award patent augment reality device transparent display',
#  'movie itune match icloud remove actually trailer annoying',
#  'train employee deal issue hang customer fucking minute wait hold',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'apple lose ground google education tablet sale aapl aapl',
#  'need portfolio defend big company look court battle',
#  'try turn problem',
#  'phone charge hour keep lose percentage shit',
#  'jdelaneyxo beta test new product isee',
#  'think 100 reason fuck',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'studio 45,000 outlet computer need battery future',
#  'year old wizkid turn nab backing hollywood star',
#  'twitter',
#  'previously deal issue annoying try reset nvram',
#  'apple dilemma apple aapl aapl',
#  'aapl new inch iphone report reason apple it...http://t.co/qntqdiytxk',
#  'aapl:6 reason apple fall yesterday...http://t.co/rvjreh9ijf',
#  'photo amazing customer service today utc store work form store hour',
#  'wish prosecute admin violation privacy criminal search seizure',
#  'aapl bidu nte stock buy list aapl bidu nte',
#  'apple iphone international price high aapl aapl',
#  '2nd day new iphone wtf switch',
#  'apple seed second 10.10.2 yosemite beta developer mac blog aapl',
#  'trade aapl free nightly update post twitter visit trade aapl free website',
#  'restart phone siri speak selection annoying fixit',
#  'studio 45,000 outlet computer need battery future',
#  'studio 45,000 outlet computer need battery future',
#  'let forget press effect stock defend ipod antitrust suit',
#  'aapl exchange iphone passport receive 550...http://t.co/diskjki4ch',
#  'iphone day break shout',
#  'studio 45,000 outlet computer need battery future',
#  'apple inc flash crash need know aapl',
#  'aapl aapl green right hope stay',
#  'video show size 12.2 inch ipad air plus mockup iphone ipad macbook aapl',
#  'debunk apple big myth \r\n\r\n \r\n\r\n aapl',
#  'yea let pay 600 dollar phone die fix shit',
#  'hey reading list safari device rock let list item delete iphone',
#  'aapl:10 good coolest tech gadget 2014 holiday season...http://t.co/teeyocbb4l',
#  'hate phone use go completely silent help',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'happy monday camera fancy iphone6plus suddenly stop work weekend instead meme',
#  'explain',
#  'studio 45,000 outlet computer need battery future',
#  'love applepay security feature pls work itune eliminate need info pay ahead payitsafe',
#  'onthisdayindigital sign deal china today 2013 finally sell iphone country',
#  'silver merchant prefer bitcoin applepay payment retail banking',
#  'give huge middle finger face',
#  'make smart elevate app year congratulation team',
#  'apple inc catch iphone6 supply lag demand motley fool aapl',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'bruh real niggas need 128 ipod touch',
#  'apple force think ipod touch demand surge aapl aapl',
#  'promoproduct supplier carry brandable compliant adapter headsaregoingtoroll mfi',
#  'apple warm social medium apple hire social media guru l.a finally twe',
#  'apple inc aapl iphone sale dent android market share aapl',
#  'find store',
#  'world murder facetime thank innovation',
#  'begin think product crap',
#  'nice1 say good app 2014',
#  'way well',
#  'hell 5gbs datum phone',
#  'macbook pro unbox macbook macbookpro startup hipst unbox',
#  'cnbctv apple take stand aapl',
#  'studio 45,000 outlet computer need battery future',
#  'apple act unfairly suppress digital music competition paul kedrosky aapl aapl',
#  'itune piss',
#  'maketh thee pesky appear end people text message',
#  'minute minute',
#  'kashka clave mind',
#  'apple drop aapl aapl',
#  'applewatch detail expose aapl',
#  'apple lower analyst see risk sharp production cut iphone plus aapl aapl',
#  'hopefully endanger life',
#  'yea let pay 600 dollar phone die fix shit',
#  'bet radioshack lol',
#  'go buy iphone6 tell stock reserve return tomorrow buy goodbye',
#  'sit wait half hour appt watch genius talk crap customer open nice',
#  'stop make installation damn bloody difficult stop ask clear space hard disk',
#  'rumour r8207 look similar certain iphone6',
#  'macbook pro non retina startup macbook macbookpro startup hipst',
#  'bad addition improve non existent customer service fail',
#  'nyc flagship store spare visit ericgarner protest',
#  'use congrat give government permission spy apple',
#  'nail build success amp brand appleid nomorepayword',
#  'apple release inch iphone mini year aapl aapl',
#  'mobile iphone nightmare iphone6',
#  'autocorrect change muslim awesome okay',
#  'short menu 3.1 live appstore',
#  'watch weekend new ad',
#  'imac catch fire use sit desk luckily nearby able sort',
#  'mark zuckerberg jab apple pricey product aapl aapl',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'fucking software update',
#  'go iphone charger past montht hank',
#  'haha tech see condosenior cookery jump opportunity',
#  'hour buzz aapl bobe amp check company make headline bell tuesday',
#  'studio 45,000 outlet computer need battery future',
#  'emanon record apple premium product average product premium price',
#  'happen itune account secretly delete non itunes music',
#  'studio 45,000 outlet computer need battery future',
#  'gay stuff fucking iphone',
#  'pop bostonholiday urbannutcracker amp krumper store boylston today dancing amp chat',
#  'aapl update alabama anti discrimination bill name apple ti...http://t.co/8rearteomu',
#  'iphone6 sale success give apple well market position thursday december',
#  'apple mean healthy',
#  'iphone long upgrade cycle expect unit sale fall aapl aapl',
#  'book grow global brand book grow stickybrand',
#  'try turn problem',
#  'probably thank ship carrier',
#  'apple aapl plan launch iphone6mini version 2015 dec 2014',
#  'world demand employer',
#  'watch dad struggle answer iphone let answer great job io',
#  'terrify suck ass',
#  'utterly rediculous take hrs simple thing like sync ringtone itune accessability horific rediculous',
#  'apple drop google map good apple map roll aapl',
#  'like new product apple',
#  'judge rule bank sue credit card breach pay value proposition intensifie',
#  'want delete email turn',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'studio 45,000 outlet computer need battery future',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'rumor roundup tale rumor blog aapl aapl',
#  'stop try like samsung choose samsung reason',
#  'happy mac yosemite file vault boot camp right thankful',
#  'apple inc sell million apple watch 2015 aapl aapl',
#  'bad day life',
#  'ipod replace set foot store world well place',
#  'love new spot',
#  'steve hayman national consulting engineer present app development umich',
#  'certify partner business collaborate',
#  'apple intraday comment update range premium user aapl stockaction trading stock mkt',
#  'happy monday camera fancy iphone6plus suddenly stop work weekend instead meme',
#  'send computer twice repair month time come new problem right',
#  'aapl think value 140 145s year.death steve job damage samsung apple',
#  'apple head trial itune update aapl',
#  'block trade detect aapl',
#  'happy backwards compatibility give app aperture money grab',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  'excellent news houseofcard 27/2 wonder yosemite amp wifi talk wk',
#  'iphone plus huge china spring aapl aapl',
#  'cool minute later yosemite macbook bad year old computer run strong win',
#  'definitely think carefully future buy support tell go wrong',
#  'evolution apple product',
#  'support say test nfc assume phone work say help',
#  'cnbctv iphone growth peak aapl',
#  'app store work',
#  'cunt printer work fucking yosemite update prick',
#  'deal take phone beat shit fuck damn twitter fuck',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'cocky ass apple talk bout fruit fuck',
#  'offensive thing lack trashcan emoji stop discrimination',
#  '.@apple need consider emoji need life',
#  '.@ikea channel hilarious new catalog bookbook time ikea',
#  'protester stage diein protest store nyc anger misplace retweet agree',
#  '.@apple patent new tech shift iphone center gravity fall land minimal damage',
#  'need send iphone cancel',
#  'link bring pre order thing',
#  'finally decide buy big ipad phone iphone6 grey normally excited smartphone',
#  'fix',
#  'studio 45,000 outlet computer need battery future',
#  'aside apple google alibaba enter connected car space forbe baba goog aapl',
#  'anti trust expert peter carstensen discuss antitrust case california federal court',
#  'yesterday tell issue .this add bad month customer service',
#  'aapl watch list at&amp;t nyse apple nasdaq aapl pandora media inc nys...http://t.co/dg5bxrxgda',
#  'good stakeholderengagement',
#  'apple tech support nice free stuff suck ringtone issue',
#  'studio 45,000 outlet computer need battery future',
#  'tim cook show apple watch chinese internet official discuss security issue aapl aapl',
#  'studio 45,000 outlet computer need battery future',
#  'dear \r\n\r\n kindly fuck .m4a format \r\n\r\n regard music listener',
#  'paper fes watch cool piece wearable tech sorry',
#  'aapl \r\n     audio auto sale apple lawsuit head court...http://t.co/kvb1l61oln',
#  'got kid',
#  'lol tryna figure file 1984',
#  'wtf live kirkby',
#  'aapl apple executive stand antitrust trial...http://t.co/mzzn6vffi4',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'wait technology analysis firm public stock symbol rong',
#  'setting page horrific',
#  'mustbuy outfit ipodnano',
#  'apple 115 fit 8.4 increase earning use 2014q3 eps=$1.42 free io app donkey stock aapl',
#  'favorite tweet',
#  'good stakeholderengagement',
#  'tear note iphone \r\n\r\n lol apple soul need save money android',
#  'justice department cite 18th century federal law unlock iphone',
#  'month cable month earpiece break',
#  'customer service good year have enjoy product zero complain thank apple',
#  'rumor surface apple iphone6s iphone7 2015 aapl',
#  'tell santa claus emoji',
#  'ipad glitche bad charge wtf',
#  'make fun french people rude new iphone',
#  'realistic song length drum track logic pro drummer proaudio',
#  'love support hourofcode workshop',
#  'studio 45,000 outlet computer need battery future',
#  'trash',
#  'apple fibonacci technical level intraday update aapl aapl',
#  'finally give india attention deserve plan set 500 store',
#  'agree prop battery life new iphone good tl_chat',
#  'learn ipod touch',
#  'love support hourofcode workshop',
#  'normal use-- abuse wrap exactly instruct fire hazard replace defective',
#  'dear apple user year remember bug like current safari fixit',
#  'new blog post gt;&gt;&gt final aapl putcallratio tuesday december 2014',
#  'wish guy port hebrew android version swap abck forth',
#  'hope automatically download bruce springsteen singe bruce espn thatwasbad',
#  ...]

# %% [markdown]
# <hr>
#
#
# ## Bolsa de Palabras
#
#
# * El siguiente paso es transformar los tweets a una bolsa de palabras de frecuencias para que sirva de entrada al modelo.
#
#
# * Dado que ya estamos trabajando con un corpus relativamente grande, es necesario reducir el diccionario de palabras (no confundir con un diccionario Python) para trabajar solo con las palabras más relevantes.
#
#
# * La implementación de la clase "*CountVectorizer*" de scikit, permite quedarnos con las palabras más relevante. Para ello podemos utilizar dos parámetros que son:
#     - **max_features**: Con este parámetro le indicamos que nos seleccione la '*X*' palabras más frecuentes del corpus. En este ejemplo **seleccionaremos las 1000 más frecuentes**.
#     - **min_df**: Con este parámetro le indicamos el número mínimo de documentos en la que tiene que aparecer la palabra para que se incluya en la bolsa de palabras. En este ejemplo **seleccionaremos 3 documentos** (tweets).
#
#
# * ***NOTA***: para más información ve la documentación de la clase "*CountVectorizer*" en: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features=1000, min_df=3)

# Pasamos los tweets normalizados a Bolsa de palabras
X = vectorizer.fit_transform(X)

# %% [markdown]
# <hr>
#
#
# ## Particionado de Datos (Train y Test)
#
# * Vamos a particionar los datos en conjunto de Train y Test.
#
#
# * Para este ejemplo nos vamos a quedar con:
#     - 80% de datos de entrenamiento
#     - 20% de datos de test

# %%
from sklearn.model_selection import train_test_split  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print('Número de Tweets para el entrenamiento: {num}'.format(num=X_train.shape[0]))
print('Número de Tweets para el test: {num}'.format(num=X_test.shape[0]))
# Out:
# Número de Tweets para el entrenamiento: 3043
# Número de Tweets para el test: 761

# %% [markdown]
# <hr>
#
#
# ## Creacción del Modelo
#
#
# * Una vez tenemos creada la bolsa de palabras, podemos usar cualquier algoritmo de aprendizaje para la clasificación.
#
#
# * Para este ejemplo vamos a usar los siguientes algoritmos de aprendizaje:
#
#     - Multinomial Naive Bayes: https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
#     - Gradient Boosting (ensemble): https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html
#
#
# * Para esta caso vamos a crear el modelo y calcular el accuracy para los datos de entrenamiento y tener una idea de que modelo puede funciona mejor:

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier

mnb = MultinomialNB()
bnb = BernoulliNB()
rf_100_5 = GradientBoostingClassifier(n_estimators=100, max_depth=5, random_state=0)
rf_100_2 = GradientBoostingClassifier(n_estimators=100,max_depth=2, random_state=0)
rf_500_5 = GradientBoostingClassifier(n_estimators=500,  max_depth=5, random_state=0)
rf_500_2 = GradientBoostingClassifier(n_estimators=500, max_depth=2, random_state=0)


clasificadores = {'Multinomial NB': mnb,
                  'Bernoulli NB': bnb,
                  'Random Forest d_100a': rf_100_5,
                  'Random Forest d_100b': rf_100_2,
                  'Random Forest d_500a': rf_500_5,
                  'Random Forest d_500b': rf_500_2}


# Ajustamos los modelos y calculamos el accuracy para los datos de entrenamiento
for k, v in clasificadores.items():
    print ('CREANDO MODELO: {clas}'.format(clas=k))
    v.fit(X_train, y_train)
# Out:
# CREANDO MODELO: Multinomial NB
# CREANDO MODELO: Bernoulli NB
# CREANDO MODELO: Random Forest d_100a
# CREANDO MODELO: Random Forest d_100b
# CREANDO MODELO: Random Forest d_500a
# CREANDO MODELO: Random Forest d_500b

# %% [markdown]
# <hr>
#
#
# ## Evaluación del Modelo
#
#
# * Para cada uno de los modelos vamos a calcular las siguientes métricas de evaluación:
#
#     1. **Accuracy**
#     2. **Precision**
#     3. **Recall**
#     4. **F1**

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score

def evaluation(model, name, X_train, y_train, X_test, y_test):
    """
    Función de devuelve en un diccionario las métricas de evaluación de 
    Accuracy, Precision, Recall y F1 para los conjuntos de datos de entrenamiento y test
        model: modelo a evaluar
        name: nombre del modelo
        X_train: Variables de entrada del conjunto de datos de entrenamiento
        y_train: Variable de salida del conjunto de datos de entrenamiento
        X_test: Variables de entrada del conjunto de datos de test
        y_test: Variable de salida del conjunto de datos de test
        return: diccionario con el nombre del modelo y el valor de las métricas
    """
    model_dict = {}
    model_dict['name'] = name
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    model_dict['accuracy_train'] = accuracy_score(y_true=y_train, y_pred=y_pred_train)
    model_dict['accuracy_tests'] = accuracy_score(y_true=y_test, y_pred=y_pred_test)
    model_dict['precision_train'] = precision_score(y_true=y_train, y_pred=y_pred_train, average='weighted')
    model_dict['precision_tests'] = precision_score(y_true=y_test, y_pred=y_pred_test, average='weighted')
    model_dict['recall_train'] = recall_score(y_true=y_train, y_pred=y_pred_train, average='weighted')
    model_dict['recall_tests'] = recall_score(y_true=y_test, y_pred=y_pred_test, average='weighted')
    model_dict['f1_train'] = f1_score(y_true=y_train, y_pred=y_pred_train, average='weighted')
    model_dict['f1_tests'] = f1_score(y_true=y_test, y_pred=y_pred_test, average='weighted')
    
    return model_dict


# Calculamos las métricas de los modelos por separado
evaluacion = list()
for key, model in clasificadores.items():
    evaluacion.append(evaluation(model=model, name=key, 
                                 X_train=X_train, y_train=y_train,
                                 X_test=X_test, y_test=y_test))

# Pasamos los resultados a un DataFrame para visualizarlos mejor
df = pd.DataFrame.from_dict(evaluacion)
df.set_index("name", inplace=True)
df
# Out:
#                       accuracy_train  accuracy_tests  precision_train  \
# name
# Multinomial NB              0.779494        0.717477         0.783073
# Bernoulli NB                0.754190        0.710907         0.766865
# Random Forest d_100a        0.833717        0.737188         0.852560
# Random Forest d_100b        0.747289        0.731932         0.785472
# Random Forest d_500a        0.837332        0.743758         0.848879
# Random Forest d_500b        0.837332        0.743758         0.848879
#
#                       precision_tests  recall_train  recall_tests  f1_train  \
# name
# Multinomial NB               0.722901      0.779494      0.717477  0.780434
# Bernoulli NB                 0.721460      0.754190      0.710907  0.755056
# Random Forest d_100a         0.737612      0.833717      0.737188  0.824276
# Random Forest d_100b         0.762766      0.747289      0.731932  0.719927
# Random Forest d_500a         0.740920      0.837332      0.743758  0.829603
# Random Forest d_500b         0.740920      0.837332      0.743758  0.829603
#
#                       f1_tests
# name
# Multinomial NB        0.719798
# Bernoulli NB          0.712930
# Random Forest d_100a  0.719109
# Random Forest d_100b  0.701422
# Random Forest d_500a  0.730419
# Random Forest d_500b  0.730419

# %% [markdown]
# * Representamos las métricas para los diferentes modelos en un gráfico de barras:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Métricas a pintar
METRICS = ["accuracy", "precision", "recall", "f1"]

# Transformamos el dataframe para pintar las gráficas con seaborn
df_plot = df.reset_index().melt(id_vars='name').rename(columns=str.title)

plt.figure(figsize=(25, 12))
pos = 1
for metric in METRICS:
    # Filtramos la métrica a pintar
    df_aux = df_plot[df_plot['Variable'].str.contains(metric)]
    
    # Pintamos la gráfica en su posición 2x2
    plt.subplot(2, 2, pos)
    sns.barplot(x='Name', y='Value', hue='Variable', data=df_aux)
    plt.title(metric.upper())
    plt.grid()
    plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
    plt.xticks(rotation=20)
    pos += 1
plt.show()

# %% [markdown]
# * Veamos las matrices de confusión de los modelos

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
# %matplotlib inline

from sklearn.metrics import confusion_matrix

# Obtenemos las Matrices de confusión
msc = list()
for k, v in clasificadores.items():
    print ('Obteniendo Matriz de Confusión de: {model}'.format(model=k))
    model = {}
    model['name'] = k
    y_pred_train = v.predict(X_train)
    y_pred_test = v.predict(X_test)
    model['confusion_matrix_train'] = confusion_matrix(y_true=y_train, y_pred=y_pred_train)
    model['confusion_matrix_test'] = confusion_matrix(y_true=y_test, y_pred=y_pred_test)
    msc.append(model)

    
# Definimos el heatmap de la matriz de confusión
def plot_confusion_matrix(cm, classes, title, cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    

# Pintamos las matrices de confusión
plt.figure(figsize=(20, 45))
pos = 0
for mc in msc:
    pos += 1
    plt.subplot(9, 2, pos)
    plot_confusion_matrix(mc['confusion_matrix_train'], classes=['positive', 'neutral', 'negative'], 
                          title='{}\nMatriz de Confusión Datos Entrenamiento'.format(mc['name']))
    pos += 1
    plt.subplot(9, 2, pos)
    plot_confusion_matrix(mc['confusion_matrix_test'], classes=['positive', 'neutral', 'negative'], 
                          title='{}\nMatriz de Confusión Datos Tests'.format(mc['name'] ))
plt.show()
# Out:
# Obteniendo Matriz de Confusión de: Multinomial NB
# Obteniendo Matriz de Confusión de: Bernoulli NB
# Obteniendo Matriz de Confusión de: Random Forest d_100a
# Obteniendo Matriz de Confusión de: Random Forest d_100b
# Obteniendo Matriz de Confusión de: Random Forest d_500a
# Obteniendo Matriz de Confusión de: Random Forest d_500b

# %% [markdown]
# <hr>
#
#
# # Repaso - Técnicas de Evaluación
#
#
# * Para evaluar los modelos obtenidos tras la aplicación de alguna de las técnicas de ML, es necesario disponer de un ***conjunto de datos*** (etiquetados o no) para ***generar el mejor modelo  posible y minimizar el error empírico***.
#
#
# * Dado un conjunto de datos, podemos enumerar los siguientes ***métodos de evaluación*** en función de cómo se dividen los datos de entrenamiento y de test:
# <span></span><br><br>
#     - **Resustitución**: Todos los datos disponibles se utilizan como datos de test y de entrenamiento.
# <span></span><br><br>
#     - **Partición (Hold Out)**: Divide los datos en dos subconjuntos: uno de entrenamiento y uno de test.
# <span></span><br><br>
# <img src="./imgs/021_tec_eval.png" style="width: 500px;"/>
# <span></span><br><br>
#     - **Validación cruzada (Cross Validation)**: Divide los datos aleatoriamente en ‘N’ bloques. Cada bloque se utiliza como test para un sistema entrenado por el resto de bloques.
# <span></span><br><br>
# <img src="./imgs/022_tec_eval.png" style="width: 500px;"/>
# <span></span><br><br>
#     - **Exclusión individual (Leave One Out)**: Este método utiliza cada dato individual como dato único de test de un sistema entrenado con todos los datos excepto el de test.
# <span></span><br><br>
# <img src="./imgs/023_tec_eval.png" style="width: 500px;"/>

# %% [markdown]
# <hr>
#
#
# # Repaso - Evaluacion de Modelos de Clasificación
#
#
# * Para los problemas de Clasificación se utilizan (entre otros) las siguientes métricas de evaluación:
#
#     - ***Accuracy***
#     - ***Precision***
#     - ***Recall***
#     - ***Specificity***
#     - ***F-score***
#     - ***Curva ROC***
#     -  ***ROC_AUC: Área sobre la curva ROC***
#
#
# * Para ver como clasifica el modelo generado usamos la denominada ***“Matriz de Confusión”*** en la cual se muestra el número de elementos que clasifica como verdaderos y falsos positivos y verdaderos y falsos negativos.
#
#
# * Veamos a continuación los detalles de las métricas de evaluación y la matriz de confusión:
#
#
# <hr>
#
#
# ## - Matriz de confusión
#
# * Cuando hablamos de clasificación tenemos que medir cuanto hemos acertado y como lo hemos acertado, por ello las ***matrices de confusión nos ayudan a ver el acierto o fallo que tiene nuestro modelo a la hora de clasificar***. La matriz de confusión tiene la siguiente forma:
#
#     - **True Positive (TP)**: Valores positivos clasificados como positivos
#     - **True Negative (TN)**: Valores negativos clasificados como negativos
#     - **False Positive (FP)**: Valores negativos clasificados como positivos
#     - **False Negative (FN)**: Valore positivos clasificados como negativos
#
# <img src="./imgs/011_Matriz_Confusion.png" style="width: 400px;"/>
#
#
# ## - Accuracy
#
# * Indica el porcentaje de acierto:
#
# $$Acuracy = \frac{TP + TN}{TP + FN + FP + TN}$$
#
# ## - Precision
#
# * Los positivos correctamente pronosticados entre todos los ejemplos pronosticados como positivos.
#
#
# * "***De lo que hemos pronosticado, cuanto hemos acertado***"
#
#
# $$Precision = \frac{TP}{TP + FP}$$
#
#
# <img src="./imgs/012_Matriz_Confusion_precision.png" style="width: 400px;"/>
#
#
#
# ## - Recall
#
#
# * Los positivos correctamente pronosticados, entre todos los ejemplos que son positivos.
#
#
# * "***De lo que hay en realidad, cuanto hemos acertado***"
#
#
# $$Recall = \frac{TP}{TP + FN}$$
#
#
# <img src="./imgs/013_Matriz_Confusion_recall.png" style="width: 400px;"/>
#
#
# ## - Specificity
#
#
# * Los negativos correctamente pronosticados, entre todos los ejemplos que son negativos.
#
#
# $$Specificity = \frac{TN}{TN + FP} = \frac{TN}{Negative}$$
#
#
# <img src="./imgs/021_eval.png" style="width: 400px;"/>
#
#
# ## - F-Score (Precision-Recall)
#
#
# * Es una media que ***combina la precisión y el recall con la media armonica de ambas medidas***.
#
#
# * Si es cercano a ***1*** significa que la clasificación realizada es buena.
#
#
# * Si es cercano a ***0*** la clasificación realizada es mala.
#
#
# * Se utiliza la media armonica, porque esta penaliza el hecho de que uno de los dos valores(el Precision o el Recall) tenga un valor bajo.
#
#
# * El ***F1*** o ***F-score*** (siendo $score=1$) se calcula de la siguiente manera:
#
#
# $$F1 = 2 \cdot \frac{Precision \cdot Recall}{Precision + Recall}$$
#
#
# * Esta medida en realidad debería de llamarse $F_\beta$ calculandose de la siguiente manera:
#
# $$F_\beta =  \frac{(1+\beta^2) \cdot Precision \cdot Recall}{\beta^2 \cdot Precision + Recall}$$
#
#
# * En función del valor que le demos a $F_\beta$ la media armónica dará más importancia a la Precision o al Recall; por ejemplo:
#
#     + $F_{0}$: Es el Recall.
#     + $F_{0.5}$: Da más peso a la Precision que al Recall.
#     + $F_{1}$: Asigna el mismo peso a la Precision que al Recall.
#     + $F_{2}$: Da más peso a la Recall que a la Precision.
#     + $F_{\infty}$: Es la Precision.
#
#
# * ***La medida del F-Score es conocida como la medida F1 porque de esta manera se calcula la media armónica entre la Precision y el Recall otorgando a ambas el mismo peso.***
#
#
# ## Curva ROC
#
#
# * La ***curva ROC*** (***R***eceiver ***O***perating ***C***haracteristic) es una gráfica que ***representa la Tasa de Verdaderos Positivos (TPR) en el eje vertical frente a la Tasa de Falsos Positivos (FPR) en el eje horizontal***.
#
#     <img src="./imgs/022_eval.png" style="width: 400px;"/>
#
# * Siendo:
# <br>
#
#     + ***TPR***: Recall
#         $$TPR = Recall = \frac{TP}{TP + FN} = \frac{TP}{Positive}$$
#     + ***FPR***: Fall-out
#         $$FPR = Fall-Out = \frac{FP}{FP + TN} = \frac{FP}{Negative}$$
#
# * Para ***construir esta curva***:
#
#     1. Nuestro ***modelo de clasificación nos tiene que devolver una probabilidad o score de pertenencia a la clase positiva y debemos de ordenar esa probabilidad o score de mayor a menor valor*** (de manera decreciente).
# <br>
#
#     2. ***Al recorrer los elementos ordenados*** vemos:
#         + Si nos encontramos un elemento que ***pertenece a la clase positiva (TPR) nos movemos verticalmente hacia arriba***.
#         + Si nos encontremos un elemento que ***pertenece a la clase negativa (FPR) nos movemos hacia la derecha***.
#
# * Por otro lado, en la curva ROC conecta siempre los puntos (0,0) y (1,1) con una recta, normalmente representada de manera punteada.
#
#
# ## - ROC_AUC: Área bajo la curva ROC
#
#
# * El ***Área Bajo la Curva ROC (Area Under Curve), es el área que queda bajo la curva ROC*** y nos vale como una medida de precisión del clasificador.
#
#
# * Un modelo que clasifique todos los elementos perfectamente, tendrá un ROC_AUC de 1.
#
#
# * Cuando se representa la curva ROC se suele dibujar una curva diagonal (discontinua) que representa un clasificador cuyos elementos tienen todos la misma probabilidad o score y esta diagonal tiene un ROC_AUC de 0,5.
#
#
# * Cuanto más cercana este nuestra curva ROC de la diagonal, significará que nuestro modelo es menos preciso a la hora de clasificar y cuanto más 'alejado' este de la diagonal, más preciso será nuestro modelo.
#
#
#
# ## - Métricas en Sckit-Learn:
#
# * Scikit-Learn tiene implementados todos estos métodos de evaluación.
#
#
# * Como norma general se le pasa como parámetros un array con la clasificación verdadera y otro array con la predicción:
#
#     - **metrics.confusion_matrix(y_true, y_pred[, …])**: Compute confusion matrix to evaluate the accuracy of a classification
#     - **metrics.accuracy_score(y_true, y_pred[, …])**: Accuracy classification score
#     - **metrics.precision_score(y_true, y_pred[, …])**: Compute the precision
#     - **metrics.recall_score(y_true, y_pred[, …])**: Compute the recall
#     - **metrics.f1_score(y_true, y_pred[, labels, …])**: Compute the F1 score, also known as balanced F-score or F-measure
#     - **metrics.classification_report(y_true, y_pred)**: Build a text report showing the main classification metrics
#     - **metrics.roc_auc_score(y_true, y_score[, …])**: Compute Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.
#     - **metrics.roc_curve(y_true, y_score[, …])**: Compute Receiver operating characteristic (ROC)
#
#
# <hr>

# %% [markdown]
# # 11 - Clasificación de textos con NLTK y Scikit-Learn
#
# * NLTK dispone de un wrapper para hacer uso de los clasificadores de Scikit-Learn.
#
#
# * Este wrapper consiste básicamente en pasarle una ***bolsa de palabras*** (en formato NLTK) y un ***objeto de alguna clase de Scikit que implemente un clasificador*** (Naive Bayes)
#
#
# * En este notebook (al igual que en el notebbok "09_Sckit_Clasificacion_textos.ipynb") vamos a ver como clasificar una serie de Tweets en Ingles sobre críticas a los productos de Apple.
#
#
# * Estos tweets estan clasificados como: *positivos*, *neutros* o *negativos*
#
#
# * El este notebook vamos a realizar los sigueintes pasos (similar que en el notebook "09_Sckit_Clasificacion_textos.ipynb" pero usando diferentes librerías).
#
#     1. Carga de los datos (tweets)
#     2. Normalización (en ingles) de los tweets con Spacy
#     3. Particionado de Datos con Scikit
#     4. Creacción de la Bolsa de Palabras con NLTK
#     5. Creacción de modelos con NLTK y Scikit
#         - Multinomial Naive Bayes
#         - Bernoulli Naive Bayes
#     6. Evaluación de los modelos

# %% [markdown]
# <hr>
#
#
# ## 1. Carga de Datos
#
#
# * El primer paso que vamos a realizar es el de cargar los datos. Para ello ***leeremos el csv con pandas*** (pasandolo a un dataframe) y posteriormente lo transformaremos en una lista de tuplas (*tweets*) donde cada tupla esta formada por:
#     - **Posición 0**: Tweet
#     - **Posición 1**: Polaridad (Positivo | Neutro | Negativo)

# %%
import pandas as pd
tweets_file = 'files/Apple_Tweets.csv'
df = pd.read_csv(tweets_file, header=None)
tweets = [tuple(x) for x in df.values]
print('Número de Tweets Cargados: {num}'.format(num=len(tweets)))
# Out:
# Número de Tweets Cargados: 3804

# %% [markdown]
# <hr>
#
#
# ## 2. Normalización
#
# * Para la normalización en este ejemplo haremos uso de ***spaCy***, de la misma mamera que se ha realizado en el notebook "09_Sckit_Clasificacion_textos.ipynb".
#
#
# * Para ***normalizar*** los tweets realizaremos las siguientes acciones:
#     1. Pasamos las frases a minúsculas.
#     2. Eliminamos los signos de puntuación.
#     3. Eliminamos las palabras con menos de 3 caracteres.
#     4. Eliminamos las Stop-Words.
#     5. Eliminamos las palabras que empiecen por '@' o 'http'.
#     6. Pasamos la palabra a su lema
#
#
# * Todos estos pasos los vamos a realizar en una misma función.
#
#
# * ***NOTA***: *De cara a la normalización de textos se pueden realizar más acciones que las que vamos a realizar, pero con estas serán más que suficientes para realizar un ejercicio con fines didácticos*

# %%
import spacy

from tqdm import tqdm

nlp = spacy.load('en_core_web_sm')

def normalize(tweets):
    """normalizamos los tweets que nos vienen en una lista de tuplas, en la posición '0' de la tupla"""
    for index, tweet in enumerate(tqdm(tweets)):
        tokens = nlp(tweet[0].lower()) # Paso el tweet a minúsculas y a un objeto de la clase Doc de Spacy
        tweet_nor = " ".join([word.lemma_ for word in tokens if (not word.is_punct)
                              and (len(word.text) > 2) and (not word.is_stop) 
                              and (not word.text.startswith('@')) and (not word.text.startswith('http'))])
        tweets[index] = (tweet_nor, tweet[1])
    return tweets

# Normalizamos los tweets
X = normalize(tweets)
# Out:
# 100%|██████████████████████████████████████| 3804/3804 [00:17<00:00, 213.00it/s]

# %% [markdown]
# <hr>
#
#
# ## 3. Particionado de Datos (Train y Test)
#
# * Vamos a particionar los datos en conjunto de Train y Test.
#
#
# * Para este ejemplo nos vamos a quedar con:
#     - 80% de datos de entrenamiento
#     - 20% de datos de test
#
#
# * Pasos:
#     1. Pasamos el Target (positivo, negativo o neutro) a una lista.
#     2. Dividimos los datos en entrenamiento y test
#
#
# * ***NOTA***: Las estructuras de datos de entrenamiento y test son tuplas de dos posiciones. La primera posición contiene el tweet normalizado y la segunda posición el target. Esta estructura la dejamos de esta manera para construir la estructura de datos que necesita la clase "classify" de NLTK.

# %%
from sklearn.model_selection import train_test_split

# Obtenemos el target
y = [y[1] for y in X] 

# Dividimos los datos en entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print('Número de Tweets para el entrenamiento: {num}'.format(num=len(X_train)))
print('Número de Tweets para el test: {num}'.format(num=len(X_test)))
# Out:
# Número de Tweets para el entrenamiento: 3043
# Número de Tweets para el test: 761

# %% [markdown]
# <hr>
#
#
# ## 4. Bolsa de Palabras (Extracción de Características)
#
#
# * NLTK necesita una determina estructura de datos de entrada para generar el modelo. Para ello necesitamos crear:
#
#     - Un Diccionario (CUIDADO no es un diccionario python) con todas las palabras del corpus.
#
#     - Una tupla que contenga:
#         1. Posición 1 (indice '0'): un Booleano por cada palabra del diccionario, para indicar si aparece o no la palabra de la frase.
#         2. Posición 2 (indice '1'): Etiqueta (target) de la frase.
#
#
# * Para ello creamos las siguientes 2 funciones:

# %%
import nltk

def get_unique_words(tweets):
    """Función que devuelve una lista con todas las palabras únicas que aparecen en las frases"""
    all_words = []
    for (tweet, sentiment) in tweets:
        all_words.extend(nltk.word_tokenize(tweet))
    return list(set(all_words))

def extract_features(document):
    """Función que crea el conjunto de entrenamiento del clasificador
       1: Toma todos los documentos del corpus
       2: Toma todas las palabras del corpus
       3: Escribre (True|False) si aparece cada palabra del corpus en la frase
    """
    document_words = set(document)
    features = {}
    for word in unique_words:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %% [markdown]
# * El siguiente paso es:
#     1. Crear el diccionario del corpus con las palabras únicas
#     2. Pasar los datos de entrenamiento y test a la estructura que necesita NLTK:
#         * Diccionario python con un Booleano por cada palabra del diccionario de palabras del corpus, para indicar si aparece o no la palabra de la frase.
#         2. Etiqueta (target) de la frase.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/carlosograndetcaballero/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Creamos el diccionario de palabras
unique_words = get_unique_words(X)

# Creamos las estructaras de datos para NLTK:
X_train_nltk = nltk.classify.apply_features(extract_features, X_train)
X_test_nltk = nltk.classify.apply_features(extract_features, X_test)

# %% [markdown]
# <hr>
#
#
# ## 5. Creacción del Modelo
#
#
# * Una vez tenemos creada la bolsa de palabras, podemos usar cualquier algoritmo de aprendizaje para la clasificación.

# %%
import nltk
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# Clasificadores
print('Entrenando Naive Bayes')
nb = nltk.classify.NaiveBayesClassifier.train(X_train_nltk)

print('Entrenando Multinomial Naive Bayes')
mnb = nltk.classify.SklearnClassifier(MultinomialNB()).train(X_train_nltk)

print('Entrenando Bernoulli Naive Bayes')
bnb = nltk.classify.SklearnClassifier(BernoulliNB()).train(X_train_nltk)

print('Entrenando Gradient Boosting')
lr = nltk.classify.SklearnClassifier(GradientBoostingClassifier(n_estimators=500,  max_depth=5, random_state=0)).train(X_train_nltk)


clasificadores = {'Naive Bayes' : nb,
                  'Multinomial Naive Bayes': mnb,
                  'Bernoulli Naive Bayes': bnb,
                  'Gradient Boosting': lr}
# Out:
# Entrenando Naive Bayes
# Entrenando Multinomial Naive Bayes
# Entrenando Bernoulli Naive Bayes
# Entrenando Gradient Boosting

# %% [markdown]
# <hr>
#
#
# ## 6. Evaluación del Modelo
#
#
# * Para cada uno de los modelos vamos a calcular las siguientes métricas de evaluación para los datos de test:
#
#     1. **Accuracy**
#     2. **Precision**
#     3. **Recall**
#     4. **F1**

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

evaluacion = list()
for k, v in clasificadores.items():
    print ('EVALUANDO MODELO: {model}'.format(model=k))
    
    # Obtengo las predicciones
    y_predictions = [v.classify(tweet[0]) for tweet in X_test_nltk]
    
    model = {}
    model['name'] = k
    model['accuracy'] = accuracy_score(y_true=y_test, y_pred=y_predictions)
    model['precision'] = precision_score(y_true=y_test, y_pred=y_predictions, average='weighted')
    model['recall'] = recall_score(y_true=y_test, y_pred=y_predictions, average='weighted')
    model['f1'] = f1_score(y_true=y_test, y_pred=y_predictions, average='weighted')
    evaluacion.append(model)

# Pasamos los resultados a un DataFrame para visualizarlos mejor
df = pd.DataFrame.from_dict(evaluacion)
df.set_index("name", inplace=True)
df

# %% [markdown]
# <hr>
#
#
# # Conclusiones
#
# * A nivel de Algoritmos de Aprendizaje (Algoritmos de Clasificación) hemos realizado los mismo que en el notebook "09_Sckit_Clasificacion_textos.ipynb" y como se puede apreciar los resultados obtenidos en este notebook son considerablemente peores.
#
#
# * Esto es debido a como construimos las ***bolsa de palabras***:
#
#     - Primer ejemplo: Seleccionamos solo las 'N' (N=1000) con más frecuencia del corpus y además filtramos aquellas palabras que no aparecen en un mínimo de 'M' (M=3) tweets.
#     - Segundo ejemplo: En este caso construimos la bolsa de palabras sin ningún tipo de restricciones, metiendo todas las palabras en la Bolsa de Palabras.
#
#
# * Por otro lado la normalización de datos realizada (tanto en un notebook como en otro) es una ***normalización de datos muy simple y trivial***. No se ha pasado a analizar con un mínimo detalle la naturaleza de los tweets (solo se han eliminado menciones '@' y enlaces 'http') y seguro que hay muchas palabras que distorsionan la clasificación.
#
#
# * Realizando una normalización muchos más extricta se hubiesen obtenido resultados mejores
